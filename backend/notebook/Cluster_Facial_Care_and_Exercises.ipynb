# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Facial_Care_and_Exercises.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    77988             Anti Ageing Face Yoga - Simple 5 steps
# 2    77988             Anti Ageing Face Yoga - Simple 5 steps
# 3    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4    41278  Anti Ageing Massage Routine For A Wrinkle Free...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Have you tried doing face yoga and do you know...
# 2  Have you tried doing face yoga and do you know...
# 3  Did you know that you can slow down ageing and...
# 4  Did you know that you can slow down ageing and...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['anti aging face yoga', 'face yoga for glowin...
# 2  ['anti aging face yoga', 'face yoga for glowin...
# 3  ['be beautiful', 'be beautiful skincare', 'ant...
# 4  ['be beautiful', 'be beautiful skincare', 'ant...
#
#                                           clean_text   keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...  face yoga
# 1  anti ageing face yoga simple 5 steps have you ...    massage
# 2  anti ageing face yoga simple 5 steps have you ...       yoga
# 3  anti ageing massage routine for a wrinkle free...  face yoga
# 4  anti ageing massage routine for a wrinkle free...    massage
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Facial Care & Exercises             0.735218       8204        368
# 1  Facial Care & Exercises             0.527572       8204        368
# 2  Facial Care & Exercises             0.587258       8204        368
# 3  Facial Care & Exercises             0.735218       4502        170
# 4  Facial Care & Exercises             0.527572       4502        170
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0            27         0.048147  130037.105593  2723.00747     35.666869
# 1            27         0.048147  130037.105593  2723.00747     35.666869
# 2            27         0.048147  130037.105593  2723.00747     35.666869
# 3            16         0.041315  130037.105593  2723.00747     35.666869
# 4            16         0.041315  130037.105593  2723.00747     35.666869
#
#    avg_engagement_rate
# 0             0.022905
# 1             0.022905
# 2             0.022905
# 3             0.022905
# 4             0.022905

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Facial_Care_and_Exercises.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    77988             Anti Ageing Face Yoga - Simple 5 steps
# 2    77988             Anti Ageing Face Yoga - Simple 5 steps
# 3    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4    41278  Anti Ageing Massage Routine For A Wrinkle Free...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Have you tried doing face yoga and do you know...
# 2  Have you tried doing face yoga and do you know...
# 3  Did you know that you can slow down ageing and...
# 4  Did you know that you can slow down ageing and...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['anti aging face yoga', 'face yoga for glowin...
# 2  ['anti aging face yoga', 'face yoga for glowin...
# 3  ['be beautiful', 'be beautiful skincare', 'ant...
# 4  ['be beautiful', 'be beautiful skincare', 'ant...
#
#                                           clean_text     keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...  [face yoga]
# 1  anti ageing face yoga simple 5 steps have you ...    [massage]
# 2  anti ageing face yoga simple 5 steps have you ...       [yoga]
# 3  anti ageing massage routine for a wrinkle free...  [face yoga]
# 4  anti ageing massage routine for a wrinkle free...    [massage]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Facial Care & Exercises             0.735218       8204        368
# 1  Facial Care & Exercises             0.527572       8204        368
# 2  Facial Care & Exercises             0.587258       8204        368
# 3  Facial Care & Exercises             0.735218       4502        170
# 4  Facial Care & Exercises             0.527572       4502        170
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0            27         0.048147  130037.105593  2723.00747     35.666869
# 1            27         0.048147  130037.105593  2723.00747     35.666869
# 2            27         0.048147  130037.105593  2723.00747     35.666869
# 3            16         0.041315  130037.105593  2723.00747     35.666869
# 4            16         0.041315  130037.105593  2723.00747     35.666869
#
#    avg_engagement_rate
# 0             0.022905
# 1             0.022905
# 2             0.022905
# 3             0.022905
# 4             0.022905

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#                       keyword  \
# 0                   face yoga
# 1                     massage
# 2                        yoga
# 3                care routine
# 4  preparing eyebrows eyelids
#
#                                            embedding
# 0  [-0.04989758, 0.0033761004, -0.017513674, 0.02...
# 1  [-0.069185466, 0.0151181575, 0.037174482, 0.06...
# 2  [-0.0073375725, -0.007475824, -0.02405119, 0.0...
# 3  [-0.066708654, 0.02712696, 0.01941102, 0.04756...
# 4  [-0.05284243, -0.07026298, 0.0035730517, 0.045...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=50, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#                       keyword  \
# 0                   face yoga
# 1                     massage
# 2                        yoga
# 3                care routine
# 4  preparing eyebrows eyelids
#
#                                            embedding  cluster_label
# 0  [-0.04989758, 0.0033761004, -0.017513674, 0.02...             15
# 1  [-0.069185466, 0.0151181575, 0.037174482, 0.06...              9
# 2  [-0.0073375725, -0.007475824, -0.02405119, 0.0...             49
# 3  [-0.066708654, 0.02712696, 0.01941102, 0.04756...             22
# 4  [-0.05284243, -0.07026298, 0.0035730517, 0.045...             11

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'moisturizers',
#  1: 'facial muscles',
#  2: 'facebrightening skincare viral',
#  3: 'yoga strengthen',
#  4: 'facial care',
#  5: 'treatments',
#  6: 'masks skin health',
#  7: 'power facial toners',
#  8: 'routine shaved',
#  9: 'massage',
#  10: 'exercises',
#  11: 'preparing eyebrows eyelids',
#  12: 'facefrosting bronzer',
#  13: 'nose contouring',
#  14: 'yoga wrinkles',
#  15: 'face yoga',
#  16: 'body exfoliant',
#  17: 'antiaging facemassage',
#  18: 'permanent straightening',
#  19: 'mensgrooming beard',
#  20: 'rosacea managing soothing',
#  21: 'facelift shorts',
#  22: 'care routine',
#  23: 'treating acne',
#  24: 'faceglow facebrightening skincare',
#  25: 'face wash cowok',
#  26: 'strengthening nourishing',
#  27: 'surgery',
#  28: 'sagging skin',
#  29: 'firming treatment',
#  30: 'eye massage',
#  31: 'antiaging faceyoga',
#  32: 'power facial',
#  33: 'facelift',
#  34: 'benefits facial',
#  35: 'facial balancing',
#  36: 'overnight masks',
#  37: 'collagen mask',
#  38: 'facial care men',
#  39: 'facial exercises',
#  40: 'shaving',
#  41: 'exercises women',
#  42: 'face massage',
#  43: 'facial toners balance',
#  44: 'facial kit',
#  45: 'strengthen facial',
#  46: 'facial muscles youthful',
#  47: 'importance moisturizers',
#  48: 'gentleman facial care',
#  49: 'yoga'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    77988             Anti Ageing Face Yoga - Simple 5 steps
# 2    77988             Anti Ageing Face Yoga - Simple 5 steps
# 3    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4    41278  Anti Ageing Massage Routine For A Wrinkle Free...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Have you tried doing face yoga and do you know...
# 2  Have you tried doing face yoga and do you know...
# 3  Did you know that you can slow down ageing and...
# 4  Did you know that you can slow down ageing and...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['anti aging face yoga', 'face yoga for glowin...
# 2  ['anti aging face yoga', 'face yoga for glowin...
# 3  ['be beautiful', 'be beautiful skincare', 'ant...
# 4  ['be beautiful', 'be beautiful skincare', 'ant...
#
#                                           clean_text     keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...  [face yoga]
# 1  anti ageing face yoga simple 5 steps have you ...    [massage]
# 2  anti ageing face yoga simple 5 steps have you ...       [yoga]
# 3  anti ageing massage routine for a wrinkle free...  [face yoga]
# 4  anti ageing massage routine for a wrinkle free...    [massage]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Facial Care & Exercises             0.735218       8204        368
# 1  Facial Care & Exercises             0.527572       8204        368
# 2  Facial Care & Exercises             0.587258       8204        368
# 3  Facial Care & Exercises             0.735218       4502        170
# 4  Facial Care & Exercises             0.527572       4502        170
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0            27         0.048147  130037.105593  2723.00747     35.666869
# 1            27         0.048147  130037.105593  2723.00747     35.666869
# 2            27         0.048147  130037.105593  2723.00747     35.666869
# 3            16         0.041315  130037.105593  2723.00747     35.666869
# 4            16         0.041315  130037.105593  2723.00747     35.666869
#
#    avg_engagement_rate new_keywords
# 0             0.022905  [face yoga]
# 1             0.022905    [massage]
# 2             0.022905       [yoga]
# 3             0.022905  [face yoga]
# 4             0.022905    [massage]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    77988             Anti Ageing Face Yoga - Simple 5 steps
# 2    77988             Anti Ageing Face Yoga - Simple 5 steps
# 3    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4    41278  Anti Ageing Massage Routine For A Wrinkle Free...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Have you tried doing face yoga and do you know...
# 2  Have you tried doing face yoga and do you know...
# 3  Did you know that you can slow down ageing and...
# 4  Did you know that you can slow down ageing and...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['anti aging face yoga', 'face yoga for glowin...
# 2  ['anti aging face yoga', 'face yoga for glowin...
# 3  ['be beautiful', 'be beautiful skincare', 'ant...
# 4  ['be beautiful', 'be beautiful skincare', 'ant...
#
#                                           clean_text     keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...  [face yoga]
# 1  anti ageing face yoga simple 5 steps have you ...    [massage]
# 2  anti ageing face yoga simple 5 steps have you ...       [yoga]
# 3  anti ageing massage routine for a wrinkle free...  [face yoga]
# 4  anti ageing massage routine for a wrinkle free...    [massage]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Facial Care & Exercises             0.735218       8204        368
# 1  Facial Care & Exercises             0.527572       8204        368
# 2  Facial Care & Exercises             0.587258       8204        368
# 3  Facial Care & Exercises             0.735218       4502        170
# 4  Facial Care & Exercises             0.527572       4502        170
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0            27         0.048147  130037.105593  2723.00747     35.666869
# 1            27         0.048147  130037.105593  2723.00747     35.666869
# 2            27         0.048147  130037.105593  2723.00747     35.666869
# 3            16         0.041315  130037.105593  2723.00747     35.666869
# 4            16         0.041315  130037.105593  2723.00747     35.666869
#
#    avg_engagement_rate new_keywords
# 0             0.022905  [face yoga]
# 1             0.022905    [massage]
# 2             0.022905       [yoga]
# 3             0.022905  [face yoga]
# 4             0.022905    [massage]
# new_keywords
# yoga                                 1736
# power facial toners                   432
# face yoga                             429
# massage                               351
# facial toners balance                 256
# exercises                             226
# importance moisturizers               208
# rosacea managing soothing             195
# facelift                              109
# moisturizers                           86
# overnight masks                        84
# care routine                           65
# facelift shorts                        64
# treating acne                          61
# masks skin health                      58
# yoga wrinkles                          58
# strengthening nourishing               50
# permanent straightening                45
# eye massage                            39
# benefits facial                        34
# facial balancing                       24
# faceglow facebrightening skincare      24
# facial muscles                         19
# facial muscles youthful                19
# surgery                                19
# power facial                           18
# sagging skin                           18
# facial exercises                       18
# gentleman facial care                  15
# facial care                            15
# facial care men                        15
# facial kit                             15
# strengthen facial                      12
# yoga strengthen                        12
# facebrightening skincare viral         12
# shaving                                11
# body exfoliant                         10
# face massage                            9
# antiaging faceyoga                      9
# face wash cowok                         9
# collagen mask                           8
# mensgrooming beard                      8
# facefrosting bronzer                    7
# nose contouring                         7
# firming treatment                       6
# exercises women                         6
# treatments                              6
# antiaging facemassage                   6
# preparing eyebrows eyelids              5
# routine shaved                          5
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    77988             Anti Ageing Face Yoga - Simple 5 steps
# 2    77988             Anti Ageing Face Yoga - Simple 5 steps
# 3    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4    41278  Anti Ageing Massage Routine For A Wrinkle Free...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Have you tried doing face yoga and do you know...
# 2  Have you tried doing face yoga and do you know...
# 3  Did you know that you can slow down ageing and...
# 4  Did you know that you can slow down ageing and...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['anti aging face yoga', 'face yoga for glowin...
# 2  ['anti aging face yoga', 'face yoga for glowin...
# 3  ['be beautiful', 'be beautiful skincare', 'ant...
# 4  ['be beautiful', 'be beautiful skincare', 'ant...
#
#                                           clean_text                 category  \
# 0  anti ageing face yoga simple 5 steps have you ...  Facial Care & Exercises
# 1  anti ageing face yoga simple 5 steps have you ...  Facial Care & Exercises
# 2  anti ageing face yoga simple 5 steps have you ...  Facial Care & Exercises
# 3  anti ageing massage routine for a wrinkle free...  Facial Care & Exercises
# 4  anti ageing massage routine for a wrinkle free...  Facial Care & Exercises
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.735218       8204        368            27         0.048147
# 1             0.527572       8204        368            27         0.048147
# 2             0.587258       8204        368            27         0.048147
# 3             0.735218       4502        170            16         0.041315
# 4             0.527572       4502        170            16         0.041315
#
#        avg_views   avg_likes  avg_comments  avg_engagement_rate   keywords
# 0  130037.105593  2723.00747     35.666869             0.022905  face yoga
# 1  130037.105593  2723.00747     35.666869             0.022905    massage
# 2  130037.105593  2723.00747     35.666869             0.022905       yoga
# 3  130037.105593  2723.00747     35.666869             0.022905  face yoga
# 4  130037.105593  2723.00747     35.666869             0.022905    massage

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0     77988             Anti Ageing Face Yoga - Simple 5 steps
# 1     77988             Anti Ageing Face Yoga - Simple 5 steps
# 2     77988             Anti Ageing Face Yoga - Simple 5 steps
# 3     41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 4     41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 5     41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 6     31540  Exercises For Chubby Face || Anti aging Face M...
# 7     31540  Exercises For Chubby Face || Anti aging Face M...
# 8     31540  Exercises For Chubby Face || Anti aging Face M...
# 9     49358            summer skin toner //home tips by soniya
# 10    92130  How to protect your eyes from holi colours #ho...
# 11    31561  5 Mins Face Massage to look 10 years younger/F...
# 12    31561  5 Mins Face Massage to look 10 years younger/F...
# 13    31561  5 Mins Face Massage to look 10 years younger/F...
# 14    20702         Mature Skin Tips for Seint IIID Foundation
# 15    56116  smooth and clean skin after face shaving hundr...
# 16    43430  Duque_Formative Assessment 5_ Preferring light...
# 17    16156         ❤️✨skin care routine ❤️✨ by )angel Sabana)
# 18    35324  बिना पैसे खर्च किये 50 की उम्र में 30 के दिखोग...
# 19    35324  बिना पैसे खर्च किये 50 की उम्र में 30 के दिखोग...
#
#                                           description  \
# 0   Have you tried doing face yoga and do you know...
# 1   Have you tried doing face yoga and do you know...
# 2   Have you tried doing face yoga and do you know...
# 3   Did you know that you can slow down ageing and...
# 4   Did you know that you can slow down ageing and...
# 5   Did you know that you can slow down ageing and...
# 6   Exercises For Chubby Face || Anti aging Face M...
# 7   Exercises For Chubby Face || Anti aging Face M...
# 8   Exercises For Chubby Face || Anti aging Face M...
# 9                                      no description
# 10                                     no description
# 11  hello viewers\n          I am sharing a face m...
# 12  hello viewers\n          I am sharing a face m...
# 13  hello viewers\n          I am sharing a face m...
# 14                                     no description
# 15                                     no description
# 16                                     no description
# 17                                     no description
# 18  Do some face exercises and look 20 years young...
# 19  Do some face exercises and look 20 years young...
#
#                                                  tags  \
# 0   ['anti aging face yoga', 'face yoga for glowin...
# 1   ['anti aging face yoga', 'face yoga for glowin...
# 2   ['anti aging face yoga', 'face yoga for glowin...
# 3   ['be beautiful', 'be beautiful skincare', 'ant...
# 4   ['be beautiful', 'be beautiful skincare', 'ant...
# 5   ['be beautiful', 'be beautiful skincare', 'ant...
# 6   ['exercises for chubby face', 'excercise for d...
# 7   ['exercises for chubby face', 'excercise for d...
# 8   ['exercises for chubby face', 'excercise for d...
# 9                                                  []
# 10                                                 []
# 11  ['#fabsana', '#antiagingfacemassage', '#skinti...
# 12  ['#fabsana', '#antiagingfacemassage', '#skinti...
# 13  ['#fabsana', '#antiagingfacemassage', '#skinti...
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  ['face exercise', 'face exercises', 'look youn...
# 19  ['face exercise', 'face exercises', 'look youn...
#
#                                            clean_text  \
# 0   anti ageing face yoga simple 5 steps have you ...
# 1   anti ageing face yoga simple 5 steps have you ...
# 2   anti ageing face yoga simple 5 steps have you ...
# 3   anti ageing massage routine for a wrinkle free...
# 4   anti ageing massage routine for a wrinkle free...
# 5   anti ageing massage routine for a wrinkle free...
# 6   exercises for chubby face anti aging face mass...
# 7   exercises for chubby face anti aging face mass...
# 8   exercises for chubby face anti aging face mass...
# 9   summer skin toner home tips by soniya no descr...
# 10  how to protect your eyes from holi colours #ho...
# 11  5 mins face massage to look 10 years younger f...
# 12  5 mins face massage to look 10 years younger f...
# 13  5 mins face massage to look 10 years younger f...
# 14  mature skin tips for seint iiid foundation no ...
# 15  smooth and clean skin after face shaving hundr...
# 16  duque formative assessment 5 preferring light ...
# 17   skin care routine by angel sabana no description
# 18  50 30 anti aging face exercises in hindi face ...
# 19  50 30 anti aging face exercises in hindi face ...
#
#                    category  category_confidence  viewCount  likeCount  \
# 0   Facial Care & Exercises             0.735218       8204        368
# 1   Facial Care & Exercises             0.527572       8204        368
# 2   Facial Care & Exercises             0.587258       8204        368
# 3   Facial Care & Exercises             0.735218       4502        170
# 4   Facial Care & Exercises             0.527572       4502        170
# 5   Facial Care & Exercises             0.587258       4502        170
# 6   Facial Care & Exercises             0.735218        117          8
# 7   Facial Care & Exercises             0.527572        117          8
# 8   Facial Care & Exercises             0.587258        117          8
# 9   Facial Care & Exercises             0.563221         41          3
# 10  Facial Care & Exercises             0.508068        761         14
# 11  Facial Care & Exercises             0.735218        110          7
# 12  Facial Care & Exercises             0.527572        110          7
# 13  Facial Care & Exercises             0.587258        110          7
# 14  Facial Care & Exercises             0.563221       3081         40
# 15  Facial Care & Exercises             0.563221       2640         46
# 16  Facial Care & Exercises             0.563221         17          3
# 17  Facial Care & Exercises             0.563221        679         23
# 18  Facial Care & Exercises             0.735218         32          1
# 19  Facial Care & Exercises             0.527572         32          1
#
#     commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0             27         0.048147  130037.105593  2723.00747     35.666869
# 1             27         0.048147  130037.105593  2723.00747     35.666869
# 2             27         0.048147  130037.105593  2723.00747     35.666869
# 3             16         0.041315  130037.105593  2723.00747     35.666869
# 4             16         0.041315  130037.105593  2723.00747     35.666869
# 5             16         0.041315  130037.105593  2723.00747     35.666869
# 6              1         0.076923  130037.105593  2723.00747     35.666869
# 7              1         0.076923  130037.105593  2723.00747     35.666869
# 8              1         0.076923  130037.105593  2723.00747     35.666869
# 9              1         0.097561  130037.105593  2723.00747     35.666869
# 10             2         0.021025  130037.105593  2723.00747     35.666869
# 11             3         0.090909  130037.105593  2723.00747     35.666869
# 12             3         0.090909  130037.105593  2723.00747     35.666869
# 13             3         0.090909  130037.105593  2723.00747     35.666869
# 14             0         0.012983  130037.105593  2723.00747     35.666869
# 15             2         0.018182  130037.105593  2723.00747     35.666869
# 16             0         0.176471  130037.105593  2723.00747     35.666869
# 17             1         0.035346  130037.105593  2723.00747     35.666869
# 18             0         0.031250  130037.105593  2723.00747     35.666869
# 19             0         0.031250  130037.105593  2723.00747     35.666869
#
#     avg_engagement_rate                    keywords                publishedAt
# 0              0.022905                   face yoga  2021-03-15 09:30:02+00:00
# 1              0.022905                     massage  2021-03-15 09:30:02+00:00
# 2              0.022905                        yoga  2021-03-15 09:30:02+00:00
# 3              0.022905                   face yoga  2021-03-17 15:01:12+00:00
# 4              0.022905                     massage  2021-03-17 15:01:12+00:00
# 5              0.022905                        yoga  2021-03-17 15:01:12+00:00
# 6              0.022905                   face yoga  2021-03-21 13:53:34+00:00
# 7              0.022905                     massage  2021-03-21 13:53:34+00:00
# 8              0.022905                        yoga  2021-03-21 13:53:34+00:00
# 9              0.022905                care routine  2021-03-24 06:09:07+00:00
# 10             0.022905  preparing eyebrows eyelids  2021-03-25 12:17:38+00:00
# 11             0.022905                   face yoga  2021-03-26 05:22:36+00:00
# 12             0.022905                     massage  2021-03-26 05:22:36+00:00
# 13             0.022905                        yoga  2021-03-26 05:22:36+00:00
# 14             0.022905                care routine  2021-03-26 23:19:09+00:00
# 15             0.022905                care routine  2021-04-04 10:01:25+00:00
# 16             0.022905                care routine  2021-04-08 09:53:52+00:00
# 17             0.022905                care routine  2021-04-09 15:04:24+00:00
# 18             0.022905                   face yoga  2021-04-10 13:46:54+00:00
# 19             0.022905                     massage  2021-04-10 13:46:54+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#                           keyword  velocity  engagement_rate    phase
#                      moisturizers      36.5         0.016763 Emerging
#                   benefits facial       4.0         0.009519 Emerging
# faceglow facebrightening skincare       4.0         0.022714 Emerging
#                      face massage       3.0         0.012474 Emerging
#                  facial balancing       3.0         0.009764 Emerging
#    facebrightening skincare viral       2.0         0.022714 Emerging
#                     collagen mask       0.5         0.024631 Emerging
#                    body exfoliant       0.5         0.023055 Emerging
#
# 🔝 Top 10 Growing keywords:
#               keyword     velocity  engagement_rate   phase
#                  yoga 1.850000e+02         0.033052 Growing
#         yoga wrinkles 5.500000e+00         0.026119 Growing
#       facial care men 2.500000e+00         0.099509 Growing
#           facial care 2.500000e+00         0.099509 Growing
# gentleman facial care 2.500000e+00         0.099509 Growing
#             exercises 2.500000e+00         0.036599 Growing
# antiaging facemassage 2.000000e+00         0.058241 Growing
#    mensgrooming beard 4.258393e-16         0.030070 Growing
#
# 🔝 Top 10 Peaking keywords:
#                 keyword  velocity  engagement_rate   phase
# permanent straightening      -1.0         0.063515 Peaking
#            care routine      -4.0         0.057439 Peaking
#      antiaging faceyoga      -0.5         0.046529 Peaking
#                 shaving      -0.5         0.042808 Peaking
#              facial kit      -0.5         0.042336 Peaking
#          routine shaved      -0.5         0.037661 Peaking
#                 massage     -12.0         0.034767 Peaking
#        facial exercises      -5.5         0.032744 Peaking
#               face yoga      -8.0         0.031202 Peaking
#                 surgery      -1.5         0.030744 Peaking
#
# 🔝 Top 10 Decaying keywords:
#                   keyword  velocity  engagement_rate    phase
#       power facial toners    -136.5         0.015205 Decaying
# rosacea managing soothing     -99.0         0.009687 Decaying
#     facial toners balance     -92.5         0.018412 Decaying
#   importance moisturizers     -58.0         0.015063 Decaying
#           overnight masks     -26.0         0.010982 Decaying
#         masks skin health     -16.0         0.011716 Decaying
#  strengthening nourishing     -14.0         0.020274 Decaying
#         strengthen facial      -8.0         0.016642 Decaying
#           yoga strengthen      -8.0         0.016642 Decaying
#           face wash cowok      -5.0         0.005621 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("fcae_keyword_trend_phases.csv", index=False)
print("✅ Saved to fcae_keyword_trend_phases.csv")
# Out:
# ✅ Saved to fcae_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#                  keyword  velocity  engagement_rate     phase
# 0  antiaging facemassage       2.0         0.058241   Growing
# 1     antiaging faceyoga      -0.5         0.046529   Peaking
# 2        benefits facial       4.0         0.009519  Emerging
# 3         body exfoliant       0.5         0.023055  Emerging
# 4           care routine      -4.0         0.057439   Peaking

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Peaking     17
# 1  Decaying     17
# 2   Growing      8
# 3  Emerging      8
