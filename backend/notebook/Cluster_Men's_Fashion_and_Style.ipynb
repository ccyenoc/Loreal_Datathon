# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Men's_Fashion_and_Style.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0    38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1    68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2    84849  beautiful hair styles for wedding or reception...
# 3    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
#
#                                          description tags  \
# 0                                     no description   []
# 1                                     no description   []
# 2                                     no description   []
# 3  Hello Youtube Family...▶ Hope You All Well !\n...   []
# 4  Hello Youtube Family...▶ Hope You All Well !\n...   []
#
#                                           clean_text      keywords  \
# 0  trendy brown hairstyle ll men #39 s unique hai...           men
# 1  unique men #39 s hairstyle ll vysucceed salon ...           men
# 2  beautiful hair styles for wedding or reception...        styles
# 3  new latest indian hair style 2021 fantastic lo...  beard styles
# 4  new latest indian hair style 2021 fantastic lo...           men
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Men's Fashion & Style             0.505982       1106          8
# 1  Men's Fashion & Style             0.505982         38          1
# 2  Men's Fashion & Style             0.595548       4678        378
# 3  Men's Fashion & Style             0.605951        703         41
# 4  Men's Fashion & Style             0.505982        703         41
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0             0         0.007233  170248.66474  6198.184082     84.203201
# 1             0         0.026316  170248.66474  6198.184082     84.203201
# 2             3         0.081445  170248.66474  6198.184082     84.203201
# 3             0         0.058321  170248.66474  6198.184082     84.203201
# 4             0         0.058321  170248.66474  6198.184082     84.203201
#
#    avg_engagement_rate
# 0             0.037021
# 1             0.037021
# 2             0.037021
# 3             0.037021
# 4             0.037021

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Men's_Fashion_and_Style.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0    38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1    68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2    84849  beautiful hair styles for wedding or reception...
# 3    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
#
#                                          description tags  \
# 0                                     no description   []
# 1                                     no description   []
# 2                                     no description   []
# 3  Hello Youtube Family...▶ Hope You All Well !\n...   []
# 4  Hello Youtube Family...▶ Hope You All Well !\n...   []
#
#                                           clean_text        keywords  \
# 0  trendy brown hairstyle ll men #39 s unique hai...           [men]
# 1  unique men #39 s hairstyle ll vysucceed salon ...           [men]
# 2  beautiful hair styles for wedding or reception...        [styles]
# 3  new latest indian hair style 2021 fantastic lo...  [beard styles]
# 4  new latest indian hair style 2021 fantastic lo...           [men]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Men's Fashion & Style             0.505982       1106          8
# 1  Men's Fashion & Style             0.505982         38          1
# 2  Men's Fashion & Style             0.595548       4678        378
# 3  Men's Fashion & Style             0.605951        703         41
# 4  Men's Fashion & Style             0.505982        703         41
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0             0         0.007233  170248.66474  6198.184082     84.203201
# 1             0         0.026316  170248.66474  6198.184082     84.203201
# 2             3         0.081445  170248.66474  6198.184082     84.203201
# 3             0         0.058321  170248.66474  6198.184082     84.203201
# 4             0         0.058321  170248.66474  6198.184082     84.203201
#
#    avg_engagement_rate
# 0             0.037021
# 1             0.037021
# 2             0.037021
# 3             0.037021
# 4             0.037021

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#            keyword                                          embedding
# 0              men  [-0.048052713, 0.044643115, -0.031075742, 0.03...
# 1           styles  [-0.050928265, 0.04636425, 0.02997894, 0.02506...
# 2     beard styles  [-0.013859727, 0.08972751, 0.03843388, -0.0348...
# 3   shorts fashion  [-0.016691957, 0.14478275, 0.025227377, 0.0395...
# 4  mens hairstyles  [-0.0024719965, 0.036659624, 0.010244152, -0.0...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=20, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#            keyword                                          embedding  \
# 0              men  [-0.048052713, 0.044643115, -0.031075742, 0.03...
# 1           styles  [-0.050928265, 0.04636425, 0.02997894, 0.02506...
# 2     beard styles  [-0.013859727, 0.08972751, 0.03843388, -0.0348...
# 3   shorts fashion  [-0.016691957, 0.14478275, 0.025227377, 0.0395...
# 4  mens hairstyles  [-0.0024719965, 0.036659624, 0.010244152, -0.0...
#
#    cluster_label
# 0              2
# 1              4
# 2             18
# 3              8
# 4              7

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'wearing',
#  1: 'men 39 wig',
#  2: 'men',
#  3: 'fashion short',
#  4: 'styles',
#  5: 'fashion trending shorts',
#  6: 'hairstyle menshairstylist',
#  7: 'men hair',
#  8: 'salon shorts',
#  9: 'jain fashion',
#  10: 'styling video men',
#  11: 'menswig',
#  12: 'menshairstylist',
#  13: 'mensstyle',
#  14: 'riddhi siddhi fashion',
#  15: 'men hottest',
#  16: 'high end men',
#  17: 'style jumpsuit',
#  18: 'beard styles',
#  19: 'mensgrooming'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0    38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1    68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2    84849  beautiful hair styles for wedding or reception...
# 3    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
#
#                                          description tags  \
# 0                                     no description   []
# 1                                     no description   []
# 2                                     no description   []
# 3  Hello Youtube Family...▶ Hope You All Well !\n...   []
# 4  Hello Youtube Family...▶ Hope You All Well !\n...   []
#
#                                           clean_text        keywords  \
# 0  trendy brown hairstyle ll men #39 s unique hai...           [men]
# 1  unique men #39 s hairstyle ll vysucceed salon ...           [men]
# 2  beautiful hair styles for wedding or reception...        [styles]
# 3  new latest indian hair style 2021 fantastic lo...  [beard styles]
# 4  new latest indian hair style 2021 fantastic lo...           [men]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Men's Fashion & Style             0.505982       1106          8
# 1  Men's Fashion & Style             0.505982         38          1
# 2  Men's Fashion & Style             0.595548       4678        378
# 3  Men's Fashion & Style             0.605951        703         41
# 4  Men's Fashion & Style             0.505982        703         41
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0             0         0.007233  170248.66474  6198.184082     84.203201
# 1             0         0.026316  170248.66474  6198.184082     84.203201
# 2             3         0.081445  170248.66474  6198.184082     84.203201
# 3             0         0.058321  170248.66474  6198.184082     84.203201
# 4             0         0.058321  170248.66474  6198.184082     84.203201
#
#    avg_engagement_rate    new_keywords
# 0             0.037021           [men]
# 1             0.037021           [men]
# 2             0.037021        [styles]
# 3             0.037021  [beard styles]
# 4             0.037021           [men]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0    38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1    68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2    84849  beautiful hair styles for wedding or reception...
# 3    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
#
#                                          description tags  \
# 0                                     no description   []
# 1                                     no description   []
# 2                                     no description   []
# 3  Hello Youtube Family...▶ Hope You All Well !\n...   []
# 4  Hello Youtube Family...▶ Hope You All Well !\n...   []
#
#                                           clean_text        keywords  \
# 0  trendy brown hairstyle ll men #39 s unique hai...           [men]
# 1  unique men #39 s hairstyle ll vysucceed salon ...           [men]
# 2  beautiful hair styles for wedding or reception...        [styles]
# 3  new latest indian hair style 2021 fantastic lo...  [beard styles]
# 4  new latest indian hair style 2021 fantastic lo...           [men]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Men's Fashion & Style             0.505982       1106          8
# 1  Men's Fashion & Style             0.505982         38          1
# 2  Men's Fashion & Style             0.595548       4678        378
# 3  Men's Fashion & Style             0.605951        703         41
# 4  Men's Fashion & Style             0.505982        703         41
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0             0         0.007233  170248.66474  6198.184082     84.203201
# 1             0         0.026316  170248.66474  6198.184082     84.203201
# 2             3         0.081445  170248.66474  6198.184082     84.203201
# 3             0         0.058321  170248.66474  6198.184082     84.203201
# 4             0         0.058321  170248.66474  6198.184082     84.203201
#
#    avg_engagement_rate    new_keywords
# 0             0.037021           [men]
# 1             0.037021           [men]
# 2             0.037021        [styles]
# 3             0.037021  [beard styles]
# 4             0.037021           [men]
# new_keywords
# men                          1606
# men hair                      200
# men 39 wig                    113
# styles                         60
# riddhi siddhi fashion          40
# salon shorts                   40
# beard styles                   33
# men hottest                    24
# fashion trending shorts        21
# fashion short                  20
# mensgrooming                   20
# styling video men              16
# hairstyle menshairstylist      12
# high end men                    9
# wearing                         7
# menswig                         6
# jain fashion                    6
# menshairstylist                 6
# mensstyle                       5
# style jumpsuit                  5
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0    38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1    68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2    84849  beautiful hair styles for wedding or reception...
# 3    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4    74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
#
#                                          description tags  \
# 0                                     no description   []
# 1                                     no description   []
# 2                                     no description   []
# 3  Hello Youtube Family...▶ Hope You All Well !\n...   []
# 4  Hello Youtube Family...▶ Hope You All Well !\n...   []
#
#                                           clean_text               category  \
# 0  trendy brown hairstyle ll men #39 s unique hai...  Men's Fashion & Style
# 1  unique men #39 s hairstyle ll vysucceed salon ...  Men's Fashion & Style
# 2  beautiful hair styles for wedding or reception...  Men's Fashion & Style
# 3  new latest indian hair style 2021 fantastic lo...  Men's Fashion & Style
# 4  new latest indian hair style 2021 fantastic lo...  Men's Fashion & Style
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.505982       1106          8             0         0.007233
# 1             0.505982         38          1             0         0.026316
# 2             0.595548       4678        378             3         0.081445
# 3             0.605951        703         41             0         0.058321
# 4             0.505982        703         41             0         0.058321
#
#       avg_views    avg_likes  avg_comments  avg_engagement_rate      keywords
# 0  170248.66474  6198.184082     84.203201             0.037021           men
# 1  170248.66474  6198.184082     84.203201             0.037021           men
# 2  170248.66474  6198.184082     84.203201             0.037021        styles
# 3  170248.66474  6198.184082     84.203201             0.037021  beard styles
# 4  170248.66474  6198.184082     84.203201             0.037021           men

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0     38162  Trendy Brown Hairstyle ll Men&#39;s Unique Hai...
# 1     68289  Unique Men&#39;s Hairstyle ll Vysucceed Salon ...
# 2     84849  beautiful hair styles for wedding or reception...
# 3     74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 4     74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 5     74604  NEW LATEST 🌟 INDIAN HAIR STYLE 2021 Fantastic ...
# 6     32028  6 IMPORTANT Grooming Tips For GIRLS To Look AT...
# 7     33212                            best opan hair style 👍👍
# 8     11384                        best hair style for girl 👍👍
# 9     57686  Mounir Mens Hair Coloring Transformation | Bea...
# 10    91800             5 Grooming Hacks EVERY GUY Should Know
# 11    53102                              #shorts, HAIRSTYLE...
# 12    88231                             #shorts not my content
# 13    80362            hairstyle with beautiful accessories 😯😯
# 14     3737                              best faded hair style
# 15     6552     Best Men’s Haircuts For 2021: Pick A New Look!
# 16    43153  How to style saree with top.Saree Draping.#sho...
# 17    36067                                #shorts #shortvideo
# 18    14338  Men&#39;s Hair Styles Compilation | Decent Hai...
# 19    14338  Men&#39;s Hair Styles Compilation | Decent Hai...
#
#                                           description  \
# 0                                      no description
# 1                                      no description
# 2                                      no description
# 3   Hello Youtube Family...▶ Hope You All Well !\n...
# 4   Hello Youtube Family...▶ Hope You All Well !\n...
# 5   Hello Youtube Family...▶ Hope You All Well !\n...
# 6   Hi girls! Here are a few basic but VERY IMPORT...
# 7   #hairstylesforgirls\n#hairstyleforgirls\n#hair...
# 8   #hairstylesforgirls\n#hairstyleforgirls\n#hair...
# 9   Mounir Mens Hair Coloring Transformation | Bea...
# 10  Give Tiege Hanley a try & get a FREE toiletry ...
# 11                                     no description
# 12                                     no description
# 13                                     no description
# 14                                     no description
# 15                 #udaysinge #dencedeewane3 #neemuch
# 16                                            #shorts
# 17                                     no description
# 18  🔔Subscribe to The Hair Trend for daily uploads...
# 19  🔔Subscribe to The Hair Trend for daily uploads...
#
#                                                  tags  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   ['ishita khanna', 'ishita khanna house tour', ...
# 7   ['best hair style', 'hair style', 'girl hair s...
# 8   ['best hair style', 'hair style', 'open hair s...
# 9   ['peaches Makeup', 'mounir salon', 'mounir sal...
# 10  ['grooming hacks for men', 'grooming tips for ...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  ['tiktok', 'tik tok', 'tiktok videos', 'hair',...
# 19  ['tiktok', 'tik tok', 'tiktok videos', 'hair',...
#
#                                            clean_text               category  \
# 0   trendy brown hairstyle ll men #39 s unique hai...  Men's Fashion & Style
# 1   unique men #39 s hairstyle ll vysucceed salon ...  Men's Fashion & Style
# 2   beautiful hair styles for wedding or reception...  Men's Fashion & Style
# 3   new latest indian hair style 2021 fantastic lo...  Men's Fashion & Style
# 4   new latest indian hair style 2021 fantastic lo...  Men's Fashion & Style
# 5   new latest indian hair style 2021 fantastic lo...  Men's Fashion & Style
# 6   6 important grooming tips for girls to look at...  Men's Fashion & Style
# 7   best opan hair style #hairstylesforgirls #hair...  Men's Fashion & Style
# 8   best hair style for girl #hairstylesforgirls #...  Men's Fashion & Style
# 9   mounir mens hair coloring transformation beaut...  Men's Fashion & Style
# 10  5 grooming hacks every guy should know give ti...  Men's Fashion & Style
# 11                   #shorts hairstyle no description  Men's Fashion & Style
# 12              #shorts not my content no description  Men's Fashion & Style
# 13  hairstyle with beautiful accessories no descri...  Men's Fashion & Style
# 14               best faded hair style no description  Men's Fashion & Style
# 15  best men s haircuts for 2021 pick a new look #...  Men's Fashion & Style
# 16  how to style saree with top saree draping #sho...  Men's Fashion & Style
# 17                 #shorts #shortvideo no description  Men's Fashion & Style
# 18  men #39 s hair styles compilation decent hair ...  Men's Fashion & Style
# 19  men #39 s hair styles compilation decent hair ...  Men's Fashion & Style
#
#     category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0              0.505982       1106          8             0         0.007233
# 1              0.505982         38          1             0         0.026316
# 2              0.595548       4678        378             3         0.081445
# 3              0.605951        703         41             0         0.058321
# 4              0.505982        703         41             0         0.058321
# 5              0.595548        703         41             0         0.058321
# 6              0.505982     594715      24729           643         0.042662
# 7              0.505982        488         10             0         0.020492
# 8              0.505982       2071         24             0         0.011589
# 9              0.505982      27730        931            27         0.034547
# 10             0.505982      19171        904            97         0.052214
# 11             0.605960        995         34             2         0.036181
# 12             0.605960        458         11             0         0.024017
# 13             0.595548         79          3             0         0.037975
# 14             0.505982       1133         21             0         0.018535
# 15             0.731904         58          3             0         0.051724
# 16             0.557088        514          6             0         0.011673
# 17             0.605960         12          2             0         0.166667
# 18             0.605951         82          2             0         0.024390
# 19             0.505982         82          2             0         0.024390
#
#        avg_views    avg_likes  avg_comments  avg_engagement_rate  \
# 0   170248.66474  6198.184082     84.203201             0.037021
# 1   170248.66474  6198.184082     84.203201             0.037021
# 2   170248.66474  6198.184082     84.203201             0.037021
# 3   170248.66474  6198.184082     84.203201             0.037021
# 4   170248.66474  6198.184082     84.203201             0.037021
# 5   170248.66474  6198.184082     84.203201             0.037021
# 6   170248.66474  6198.184082     84.203201             0.037021
# 7   170248.66474  6198.184082     84.203201             0.037021
# 8   170248.66474  6198.184082     84.203201             0.037021
# 9   170248.66474  6198.184082     84.203201             0.037021
# 10  170248.66474  6198.184082     84.203201             0.037021
# 11  170248.66474  6198.184082     84.203201             0.037021
# 12  170248.66474  6198.184082     84.203201             0.037021
# 13  170248.66474  6198.184082     84.203201             0.037021
# 14  170248.66474  6198.184082     84.203201             0.037021
# 15  170248.66474  6198.184082     84.203201             0.037021
# 16  170248.66474  6198.184082     84.203201             0.037021
# 17  170248.66474  6198.184082     84.203201             0.037021
# 18  170248.66474  6198.184082     84.203201             0.037021
# 19  170248.66474  6198.184082     84.203201             0.037021
#
#           keywords                publishedAt
# 0              men  2021-03-17 08:30:01+00:00
# 1              men  2021-03-17 08:33:25+00:00
# 2           styles  2021-03-17 11:11:47+00:00
# 3     beard styles  2021-03-25 04:00:06+00:00
# 4              men  2021-03-25 04:00:06+00:00
# 5           styles  2021-03-25 04:00:06+00:00
# 6              men  2021-03-25 07:30:00+00:00
# 7              men  2021-03-25 15:31:53+00:00
# 8              men  2021-03-25 15:32:06+00:00
# 9              men  2021-03-26 06:00:56+00:00
# 10             men  2021-03-28 13:00:12+00:00
# 11    salon shorts  2021-03-29 12:08:43+00:00
# 12    salon shorts  2021-04-02 18:24:20+00:00
# 13          styles  2021-04-03 05:12:06+00:00
# 14             men  2021-04-03 16:04:16+00:00
# 15        men hair  2021-04-04 05:06:07+00:00
# 16  style jumpsuit  2021-04-06 12:45:28+00:00
# 17    salon shorts  2021-04-09 04:30:48+00:00
# 18    beard styles  2021-04-10 22:55:46+00:00
# 19             men  2021-04-10 22:55:46+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#                   keyword     velocity  engagement_rate    phase
# hairstyle menshairstylist 5.000000e-01         0.027964 Emerging
#           menshairstylist 5.000000e-01         0.031878 Emerging
#                   menswig 5.000000e-01         0.025028 Emerging
#                men 39 wig 5.000000e-01         0.030716 Emerging
#   fashion trending shorts 5.110632e-16         0.021429 Emerging
#
# 🔝 Top 10 Growing keywords:
#      keyword     velocity  engagement_rate   phase
#       styles 5.000000e-01         0.040215 Growing
# mensgrooming 1.252154e-15         0.039113 Growing
#
# 🔝 Top 10 Peaking keywords:
#               keyword      velocity  engagement_rate   phase
#               wearing -1.500000e+00         0.113876 Peaking
#             mensstyle -8.265273e-17         0.067591 Peaking
#          jain fashion -5.000000e-01         0.052333 Peaking
#         fashion short -1.500000e+00         0.050447 Peaking
# riddhi siddhi fashion -3.000000e+00         0.050447 Peaking
#          salon shorts -2.376568e-16         0.045759 Peaking
#                   men -5.500000e+00         0.041321 Peaking
#           men hottest -1.500000e+00         0.038944 Peaking
#
# 🔝 Top 10 Decaying keywords:
#           keyword      velocity  engagement_rate    phase
# styling video men -4.000000e+00         0.029185 Decaying
#          men hair -3.500000e+00         0.025816 Decaying
#      high end men -3.000000e+00         0.004183 Decaying
#      beard styles -5.000000e-01         0.038246 Decaying
#    style jumpsuit -8.265273e-17         0.032881 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("Men's_Fashion_and_Style_keyword_trend_phases.csv", index=False)
print("✅ Saved to Men's_Fashion_and_Style_keyword_trend_phases.csv")
# Out:
# ✅ Saved to Men's_Fashion_and_Style_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#                      keyword      velocity  engagement_rate     phase
# 0               beard styles -5.000000e-01         0.038246  Decaying
# 1              fashion short -1.500000e+00         0.050447   Peaking
# 2    fashion trending shorts  5.110632e-16         0.021429  Emerging
# 3  hairstyle menshairstylist  5.000000e-01         0.027964  Emerging
# 4               high end men -3.000000e+00         0.004183  Decaying

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Peaking      8
# 1  Decaying      5
# 2  Emerging      5
# 3   Growing      2
