# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Makeup_and_Cosmetics.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3      537              Transformation hair colour correction
# 4      537              Transformation hair colour correction
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3  Helping clients achieve there hair goals. \nco...
# 4  Helping clients achieve there hair goals. \nco...
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                 []
# 4                                                 []
#
#                                           clean_text  keywords  \
# 0  five best anti ageing facial exercises look yo...      face
# 1  five best anti ageing facial exercises look yo...  products
# 2  five best anti ageing facial exercises look yo...      skin
# 3  transformation hair colour correction helping ...      face
# 4  transformation hair colour correction helping ...  products
#
#              category  category_confidence  viewCount  likeCount  \
# 0  Makeup & Cosmetics             0.572939      161.0        4.0
# 1  Makeup & Cosmetics             0.561776      161.0        4.0
# 2  Makeup & Cosmetics             0.639257      161.0        4.0
# 3  Makeup & Cosmetics             0.572939       83.0        2.0
# 4  Makeup & Cosmetics             0.561776       83.0        2.0
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0           1.0         0.031056  251450.921497  7417.02492     73.241087
# 1           1.0         0.031056  251450.921497  7417.02492     73.241087
# 2           1.0         0.031056  251450.921497  7417.02492     73.241087
# 3           0.0         0.024096  251450.921497  7417.02492     73.241087
# 4           0.0         0.024096  251450.921497  7417.02492     73.241087
#
#    avg_engagement_rate
# 0             0.040919
# 1             0.040919
# 2             0.040919
# 3             0.040919
# 4             0.040919

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Makeup_and_Cosmetics.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3      537              Transformation hair colour correction
# 4      537              Transformation hair colour correction
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3  Helping clients achieve there hair goals. \nco...
# 4  Helping clients achieve there hair goals. \nco...
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                 []
# 4                                                 []
#
#                                           clean_text    keywords  \
# 0  five best anti ageing facial exercises look yo...      [face]
# 1  five best anti ageing facial exercises look yo...  [products]
# 2  five best anti ageing facial exercises look yo...      [skin]
# 3  transformation hair colour correction helping ...      [face]
# 4  transformation hair colour correction helping ...  [products]
#
#              category  category_confidence  viewCount  likeCount  \
# 0  Makeup & Cosmetics             0.572939      161.0        4.0
# 1  Makeup & Cosmetics             0.561776      161.0        4.0
# 2  Makeup & Cosmetics             0.639257      161.0        4.0
# 3  Makeup & Cosmetics             0.572939       83.0        2.0
# 4  Makeup & Cosmetics             0.561776       83.0        2.0
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0           1.0         0.031056  251450.921497  7417.02492     73.241087
# 1           1.0         0.031056  251450.921497  7417.02492     73.241087
# 2           1.0         0.031056  251450.921497  7417.02492     73.241087
# 3           0.0         0.024096  251450.921497  7417.02492     73.241087
# 4           0.0         0.024096  251450.921497  7417.02492     73.241087
#
#    avg_engagement_rate
# 0             0.040919
# 1             0.040919
# 2             0.040919
# 3             0.040919
# 4             0.040919

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#       keyword                                          embedding
# 0        face  [-0.07711064, 0.08789431, -0.021635368, 0.0093...
# 1    products  [-0.058791332, 0.0050579375, -0.006295959, -0....
# 2        skin  [-0.025659306, 0.08185282, 0.021862969, 0.0747...
# 3  best salon  [-0.01064655, -0.044945385, -0.018014941, -0.0...
# 4        palm  [-0.032893706, 0.007090812, -0.04114384, -0.00...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=40, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#       keyword                                          embedding  \
# 0        face  [-0.07711064, 0.08789431, -0.021635368, 0.0093...
# 1    products  [-0.058791332, 0.0050579375, -0.006295959, -0....
# 2        skin  [-0.025659306, 0.08185282, 0.021862969, 0.0747...
# 3  best salon  [-0.01064655, -0.044945385, -0.018014941, -0.0...
# 4        palm  [-0.032893706, 0.007090812, -0.04114384, -0.00...
#
#    cluster_label
# 0             35
# 1             32
# 2             22
# 3             30
# 4             19

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'belle',
#  1: 'eyeliner eyeshadow',
#  2: 'beauty makeup',
#  3: 'hair perm',
#  4: 'mask',
#  5: 'beautiful skin',
#  6: 'life',
#  7: 'make',
#  8: 'projects',
#  9: 'lip',
#  10: 'makeuptutorial makeupforblackwomen glammakeup',
#  11: 'lipstick',
#  12: 'outfit',
#  13: 'foundation',
#  14: 'makeup makeuptutorial',
#  15: 'tanning',
#  16: 'mascara',
#  17: 'hot',
#  18: 'shorts makeup',
#  19: 'clean',
#  20: 'serum',
#  21: 'perfume',
#  22: 'beauty skin',
#  23: 'powder skin',
#  24: 'makeup products',
#  25: 'hair stylist',
#  26: 'art',
#  27: 'styling',
#  28: 'fav',
#  29: 'skin glow',
#  30: 'hair salon',
#  31: 'blush beauty',
#  32: 'business',
#  33: 'bridal makeup',
#  34: 'cosmetics',
#  35: 'facial',
#  36: 'makeuplover beauty',
#  37: 'eyes',
#  38: 'eyebrows',
#  39: 'shop'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3      537              Transformation hair colour correction
# 4      537              Transformation hair colour correction
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3  Helping clients achieve there hair goals. \nco...
# 4  Helping clients achieve there hair goals. \nco...
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                 []
# 4                                                 []
#
#                                           clean_text    keywords  \
# 0  five best anti ageing facial exercises look yo...      [face]
# 1  five best anti ageing facial exercises look yo...  [products]
# 2  five best anti ageing facial exercises look yo...      [skin]
# 3  transformation hair colour correction helping ...      [face]
# 4  transformation hair colour correction helping ...  [products]
#
#              category  category_confidence  viewCount  likeCount  \
# 0  Makeup & Cosmetics             0.572939      161.0        4.0
# 1  Makeup & Cosmetics             0.561776      161.0        4.0
# 2  Makeup & Cosmetics             0.639257      161.0        4.0
# 3  Makeup & Cosmetics             0.572939       83.0        2.0
# 4  Makeup & Cosmetics             0.561776       83.0        2.0
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0           1.0         0.031056  251450.921497  7417.02492     73.241087
# 1           1.0         0.031056  251450.921497  7417.02492     73.241087
# 2           1.0         0.031056  251450.921497  7417.02492     73.241087
# 3           0.0         0.024096  251450.921497  7417.02492     73.241087
# 4           0.0         0.024096  251450.921497  7417.02492     73.241087
#
#    avg_engagement_rate   new_keywords
# 0             0.040919       [facial]
# 1             0.040919     [business]
# 2             0.040919  [beauty skin]
# 3             0.040919       [facial]
# 4             0.040919     [business]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3      537              Transformation hair colour correction
# 4      537              Transformation hair colour correction
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3  Helping clients achieve there hair goals. \nco...
# 4  Helping clients achieve there hair goals. \nco...
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                 []
# 4                                                 []
#
#                                           clean_text    keywords  \
# 0  five best anti ageing facial exercises look yo...      [face]
# 1  five best anti ageing facial exercises look yo...  [products]
# 2  five best anti ageing facial exercises look yo...      [skin]
# 3  transformation hair colour correction helping ...      [face]
# 4  transformation hair colour correction helping ...  [products]
#
#              category  category_confidence  viewCount  likeCount  \
# 0  Makeup & Cosmetics             0.572939      161.0        4.0
# 1  Makeup & Cosmetics             0.561776      161.0        4.0
# 2  Makeup & Cosmetics             0.639257      161.0        4.0
# 3  Makeup & Cosmetics             0.572939       83.0        2.0
# 4  Makeup & Cosmetics             0.561776       83.0        2.0
#
#    commentCount  engagement_rate      avg_views   avg_likes  avg_comments  \
# 0           1.0         0.031056  251450.921497  7417.02492     73.241087
# 1           1.0         0.031056  251450.921497  7417.02492     73.241087
# 2           1.0         0.031056  251450.921497  7417.02492     73.241087
# 3           0.0         0.024096  251450.921497  7417.02492     73.241087
# 4           0.0         0.024096  251450.921497  7417.02492     73.241087
#
#    avg_engagement_rate   new_keywords
# 0             0.040919       [facial]
# 1             0.040919     [business]
# 2             0.040919  [beauty skin]
# 3             0.040919       [facial]
# 4             0.040919     [business]
# new_keywords
# beauty skin                                      42574
# facial                                           37037
# business                                          7103
# beauty makeup                                     4803
# hot                                               3583
# lipstick                                          2651
# lip                                               2356
# eyes                                              2055
# life                                              1513
# bridal makeup                                     1334
# mask                                              1050
# powder skin                                       1022
# clean                                             1004
# hair stylist                                       926
# serum                                              924
# art                                                863
# styling                                            851
# eyeliner eyeshadow                                 791
# foundation                                         711
# makeup makeuptutorial                              617
# tanning                                            580
# projects                                           477
# makeup products                                    403
# mascara                                            393
# perfume                                            388
# outfit                                             386
# blush beauty                                       345
# eyebrows                                           339
# skin glow                                          327
# cosmetics                                          319
# makeuptutorial makeupforblackwomen glammakeup      287
# shop                                               263
# make                                               256
# shorts makeup                                      228
# fav                                                211
# beautiful skin                                     208
# hair salon                                         139
# belle                                              132
# makeuplover beauty                                  97
# hair perm                                           12
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3      537              Transformation hair colour correction
# 4      537              Transformation hair colour correction
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3  Helping clients achieve there hair goals. \nco...
# 4  Helping clients achieve there hair goals. \nco...
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                 []
# 4                                                 []
#
#                                           clean_text            category  \
# 0  five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 1  five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 2  five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 3  transformation hair colour correction helping ...  Makeup & Cosmetics
# 4  transformation hair colour correction helping ...  Makeup & Cosmetics
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.572939      161.0        4.0           1.0         0.031056
# 1             0.561776      161.0        4.0           1.0         0.031056
# 2             0.639257      161.0        4.0           1.0         0.031056
# 3             0.572939       83.0        2.0           0.0         0.024096
# 4             0.561776       83.0        2.0           0.0         0.024096
#
#        avg_views   avg_likes  avg_comments  avg_engagement_rate     keywords
# 0  251450.921497  7417.02492     73.241087             0.040919       facial
# 1  251450.921497  7417.02492     73.241087             0.040919     business
# 2  251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 3  251450.921497  7417.02492     73.241087             0.040919       facial
# 4  251450.921497  7417.02492     73.241087             0.040919     business

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0      6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 2      6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 3       537              Transformation hair colour correction
# 4       537              Transformation hair colour correction
# 5       537              Transformation hair colour correction
# 6     25429                        Huda Beauty UK London Event
# 7     25429                        Huda Beauty UK London Event
# 8     25429                        Huda Beauty UK London Event
# 9     26244  The Jersey Beauty guide to using Dermalogica e...
# 10    26244  The Jersey Beauty guide to using Dermalogica e...
# 11    26244  The Jersey Beauty guide to using Dermalogica e...
# 12    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
# 13    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
# 14    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
# 15    86296               CRYSTALS AND TARAS AVON FASHION SHOW
# 16    86296               CRYSTALS AND TARAS AVON FASHION SHOW
# 17    86296               CRYSTALS AND TARAS AVON FASHION SHOW
# 18    48321  Beard transformation Before and After | D-Tan ...
# 19    48321  Beard transformation Before and After | D-Tan ...
#
#                                           description  \
# 0   #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1   #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 2   #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 3   Helping clients achieve there hair goals. \nco...
# 4   Helping clients achieve there hair goals. \nco...
# 5   Helping clients achieve there hair goals. \nco...
# 6   We worked with the HUDA Beauty UK team to film...
# 7   We worked with the HUDA Beauty UK team to film...
# 8   We worked with the HUDA Beauty UK team to film...
# 9   In this video, Jen from Jersey Beauty chats to...
# 10  In this video, Jen from Jersey Beauty chats to...
# 11  In this video, Jen from Jersey Beauty chats to...
# 12                                     no description
# 13                                     no description
# 14                                     no description
# 15  AVON FASHION-EASY LIVING COLLECTION \nBEST FRI...
# 16  AVON FASHION-EASY LIVING COLLECTION \nBEST FRI...
# 17  AVON FASHION-EASY LIVING COLLECTION \nBEST FRI...
# 18  Beard transformation Before and After | D-Tan ...
# 19  Beard transformation Before and After | D-Tan ...
#
#                                                  tags  \
# 0   ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1   ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 2   ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   ['huda beauty', 'huda london', 'huda london ev...
# 7   ['huda beauty', 'huda london', 'huda london ev...
# 8   ['huda beauty', 'huda london', 'huda london ev...
# 9   ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 10  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 11  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  ['Beard transformation before and After', 'Bea...
# 19  ['Beard transformation before and After', 'Bea...
#
#                                            clean_text            category  \
# 0   five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 1   five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 2   five best anti ageing facial exercises look yo...  Makeup & Cosmetics
# 3   transformation hair colour correction helping ...  Makeup & Cosmetics
# 4   transformation hair colour correction helping ...  Makeup & Cosmetics
# 5   transformation hair colour correction helping ...  Makeup & Cosmetics
# 6   huda beauty uk london event we worked with the...  Makeup & Cosmetics
# 7   huda beauty uk london event we worked with the...  Makeup & Cosmetics
# 8   huda beauty uk london event we worked with the...  Makeup & Cosmetics
# 9   the jersey beauty guide to using dermalogica e...  Makeup & Cosmetics
# 10  the jersey beauty guide to using dermalogica e...  Makeup & Cosmetics
# 11  the jersey beauty guide to using dermalogica e...  Makeup & Cosmetics
# 12  tone n glow face wash for crystal clear skin n...  Makeup & Cosmetics
# 13  tone n glow face wash for crystal clear skin n...  Makeup & Cosmetics
# 14  tone n glow face wash for crystal clear skin n...  Makeup & Cosmetics
# 15  crystals and taras avon fashion show avon fash...  Makeup & Cosmetics
# 16  crystals and taras avon fashion show avon fash...  Makeup & Cosmetics
# 17  crystals and taras avon fashion show avon fash...  Makeup & Cosmetics
# 18  beard transformation before and after d tan fa...  Makeup & Cosmetics
# 19  beard transformation before and after d tan fa...  Makeup & Cosmetics
#
#     category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0              0.572939      161.0        4.0           1.0         0.031056
# 1              0.561776      161.0        4.0           1.0         0.031056
# 2              0.639257      161.0        4.0           1.0         0.031056
# 3              0.572939       83.0        2.0           0.0         0.024096
# 4              0.561776       83.0        2.0           0.0         0.024096
# 5              0.639257       83.0        2.0           0.0         0.024096
# 6              0.572939      121.0        3.0           1.0         0.033058
# 7              0.561776      121.0        3.0           1.0         0.033058
# 8              0.639257      121.0        3.0           1.0         0.033058
# 9              0.572939     2228.0       28.0           0.0         0.012567
# 10             0.561776     2228.0       28.0           0.0         0.012567
# 11             0.639257     2228.0       28.0           0.0         0.012567
# 12             0.572939    25959.0      341.0         166.0         0.019531
# 13             0.561776    25959.0      341.0         166.0         0.019531
# 14             0.639257    25959.0      341.0         166.0         0.019531
# 15             0.572939      197.0        6.0           3.0         0.045685
# 16             0.561776      197.0        6.0           3.0         0.045685
# 17             0.639257      197.0        6.0           3.0         0.045685
# 18             0.572939      254.0       10.0           1.0         0.043307
# 19             0.561776      254.0       10.0           1.0         0.043307
#
#         avg_views   avg_likes  avg_comments  avg_engagement_rate     keywords  \
# 0   251450.921497  7417.02492     73.241087             0.040919       facial
# 1   251450.921497  7417.02492     73.241087             0.040919     business
# 2   251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 3   251450.921497  7417.02492     73.241087             0.040919       facial
# 4   251450.921497  7417.02492     73.241087             0.040919     business
# 5   251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 6   251450.921497  7417.02492     73.241087             0.040919       facial
# 7   251450.921497  7417.02492     73.241087             0.040919     business
# 8   251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 9   251450.921497  7417.02492     73.241087             0.040919       facial
# 10  251450.921497  7417.02492     73.241087             0.040919     business
# 11  251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 12  251450.921497  7417.02492     73.241087             0.040919       facial
# 13  251450.921497  7417.02492     73.241087             0.040919     business
# 14  251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 15  251450.921497  7417.02492     73.241087             0.040919       facial
# 16  251450.921497  7417.02492     73.241087             0.040919     business
# 17  251450.921497  7417.02492     73.241087             0.040919  beauty skin
# 18  251450.921497  7417.02492     73.241087             0.040919       facial
# 19  251450.921497  7417.02492     73.241087             0.040919     business
#
#                   publishedAt
# 0   2020-01-01 14:28:59+00:00
# 1   2020-01-01 14:28:59+00:00
# 2   2020-01-01 14:28:59+00:00
# 3   2020-01-01 16:31:43+00:00
# 4   2020-01-01 16:31:43+00:00
# 5   2020-01-01 16:31:43+00:00
# 6   2020-01-02 13:08:50+00:00
# 7   2020-01-02 13:08:50+00:00
# 8   2020-01-02 13:08:50+00:00
# 9   2020-01-03 15:32:39+00:00
# 10  2020-01-03 15:32:39+00:00
# 11  2020-01-03 15:32:39+00:00
# 12  2020-01-03 19:01:31+00:00
# 13  2020-01-03 19:01:31+00:00
# 14  2020-01-03 19:01:31+00:00
# 15  2020-01-04 06:13:56+00:00
# 16  2020-01-04 06:13:56+00:00
# 17  2020-01-04 06:13:56+00:00
# 18  2020-01-04 09:58:50+00:00
# 19  2020-01-04 09:58:50+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#        keyword  velocity  engagement_rate    phase
# beautiful skin      34.0         0.034707 Emerging
#       eyebrows       4.5         0.032408 Emerging
#       projects       1.5         0.031321 Emerging
#          belle       0.5         0.037856 Emerging
#      hair perm       0.5         0.029475 Emerging
#     hair salon       0.5         0.034351 Emerging
#
# 🔝 Top 10 Growing keywords:
#            keyword     velocity  engagement_rate   phase
#                art 4.500000e+00         0.048867 Growing
#       blush beauty 1.000000e+00         0.058166 Growing
# eyeliner eyeshadow 4.631959e-15         0.050427 Growing
#
# 🔝 Top 10 Peaking keywords:
#               keyword  velocity  engagement_rate   phase
#         bridal makeup     -11.0         0.059937 Peaking
#         shorts makeup      -0.5         0.058645 Peaking
#              business     -85.0         0.053423 Peaking
#         beauty makeup     -48.5         0.051602 Peaking
#                facial    -328.5         0.049900 Peaking
#           beauty skin    -401.0         0.049408 Peaking
# makeup makeuptutorial     -16.0         0.048553 Peaking
#               perfume      -8.5         0.048011 Peaking
#       makeup products     -19.0         0.046879 Peaking
#            foundation     -16.5         0.046105 Peaking
#
# 🔝 Top 10 Decaying keywords:
#            keyword  velocity  engagement_rate    phase
#                lip     -44.0         0.038205 Decaying
#              serum     -19.5         0.039646 Decaying
#            tanning     -17.5         0.036867 Decaying
#           lipstick     -13.5         0.038033 Decaying
#       hair stylist     -13.0         0.037897 Decaying
#            styling     -12.0         0.038759 Decaying
# makeuplover beauty     -11.5         0.036849 Decaying
#        powder skin     -11.5         0.038035 Decaying
#            mascara      -4.0         0.037322 Decaying
#                fav      -3.5         0.040587 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("Makeup_and_Cosmetics_keyword_trend_phases.csv", index=False)
print("✅ Saved to Makeup_and_Cosmetics_keyword_trend_phases.csv")
# Out:
# ✅ Saved to Makeup_and_Cosmetics_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#           keyword  velocity  engagement_rate     phase
# 0             art       4.5         0.048867   Growing
# 1  beautiful skin      34.0         0.034707  Emerging
# 2   beauty makeup     -48.5         0.051602   Peaking
# 3     beauty skin    -401.0         0.049408   Peaking
# 4           belle       0.5         0.037856  Emerging

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Peaking     17
# 1  Decaying     14
# 2  Emerging      6
# 3   Growing      3
