# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Skincare_and_Anti-Aging.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2    31540  Exercises For Chubby Face || Anti aging Face M...
# 3    49358            summer skin toner //home tips by soniya
# 4    31561  5 Mins Face Massage to look 10 years younger/F...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Did you know that you can slow down ageing and...
# 2  Exercises For Chubby Face || Anti aging Face M...
# 3                                     no description
# 4  hello viewers\n          I am sharing a face m...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['be beautiful', 'be beautiful skincare', 'ant...
# 2  ['exercises for chubby face', 'excercise for d...
# 3                                                 []
# 4  ['#fabsana', '#antiagingfacemassage', '#skinti...
#
#                                           clean_text           keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...         anti aging
# 1  anti ageing massage routine for a wrinkle free...         anti aging
# 2  exercises for chubby face anti aging face mass...         anti aging
# 3  summer skin toner home tips by soniya no descr...  skin care routine
# 4  5 mins face massage to look 10 years younger f...         anti aging
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Skincare & Anti-Aging             0.588283       8204        368
# 1  Skincare & Anti-Aging             0.588283       4502        170
# 2  Skincare & Anti-Aging             0.588283        117          8
# 3  Skincare & Anti-Aging             0.682736         41          3
# 4  Skincare & Anti-Aging             0.588283        110          7
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0            27         0.048147  104589.08836  2484.359585     21.462159
# 1            16         0.041315  104589.08836  2484.359585     21.462159
# 2             1         0.076923  104589.08836  2484.359585     21.462159
# 3             1         0.097561  104589.08836  2484.359585     21.462159
# 4             3         0.090909  104589.08836  2484.359585     21.462159
#
#    avg_engagement_rate
# 0             0.021585
# 1             0.021585
# 2             0.021585
# 3             0.021585
# 4             0.021585

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Skincare_and_Anti-Aging.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2    31540  Exercises For Chubby Face || Anti aging Face M...
# 3    49358            summer skin toner //home tips by soniya
# 4    31561  5 Mins Face Massage to look 10 years younger/F...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Did you know that you can slow down ageing and...
# 2  Exercises For Chubby Face || Anti aging Face M...
# 3                                     no description
# 4  hello viewers\n          I am sharing a face m...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['be beautiful', 'be beautiful skincare', 'ant...
# 2  ['exercises for chubby face', 'excercise for d...
# 3                                                 []
# 4  ['#fabsana', '#antiagingfacemassage', '#skinti...
#
#                                           clean_text             keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...         [anti aging]
# 1  anti ageing massage routine for a wrinkle free...         [anti aging]
# 2  exercises for chubby face anti aging face mass...         [anti aging]
# 3  summer skin toner home tips by soniya no descr...  [skin care routine]
# 4  5 mins face massage to look 10 years younger f...         [anti aging]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Skincare & Anti-Aging             0.588283       8204        368
# 1  Skincare & Anti-Aging             0.588283       4502        170
# 2  Skincare & Anti-Aging             0.588283        117          8
# 3  Skincare & Anti-Aging             0.682736         41          3
# 4  Skincare & Anti-Aging             0.588283        110          7
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0            27         0.048147  104589.08836  2484.359585     21.462159
# 1            16         0.041315  104589.08836  2484.359585     21.462159
# 2             1         0.076923  104589.08836  2484.359585     21.462159
# 3             1         0.097561  104589.08836  2484.359585     21.462159
# 4             3         0.090909  104589.08836  2484.359585     21.462159
#
#    avg_engagement_rate
# 0             0.021585
# 1             0.021585
# 2             0.021585
# 3             0.021585
# 4             0.021585

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#              keyword                                          embedding
# 0         anti aging  [-0.02247137, 0.120942466, 0.045491315, 0.0771...
# 1  skin care routine  [-0.02117496, 0.07472372, 0.052825402, 0.08036...
# 2    ersas skin care  [-0.038992472, 0.054183535, 1.2934526e-05, 0.0...
# 3    skincareroutine  [-0.011234583, 0.021004131, -0.051165044, 0.07...
# 4     best skin care  [-0.030920994, 0.060996383, 0.07058944, 0.0011...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=20, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#              keyword                                          embedding  \
# 0         anti aging  [-0.02247137, 0.120942466, 0.045491315, 0.0771...
# 1  skin care routine  [-0.02117496, 0.07472372, 0.052825402, 0.08036...
# 2    ersas skin care  [-0.038992472, 0.054183535, 1.2934526e-05, 0.0...
# 3    skincareroutine  [-0.011234583, 0.021004131, -0.051165044, 0.07...
# 4     best skin care  [-0.030920994, 0.060996383, 0.07058944, 0.0011...
#
#    cluster_label
# 0              3
# 1              1
# 2             16
# 3             13
# 4              1

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'unachilenaenuk woman skincare',
#  1: 'skincare tips',
#  2: 'hydrated skin',
#  3: 'anti aging face',
#  4: 'wrinkles antiaging',
#  5: 'solutions skin concerns',
#  6: 'skincare kbeauty koreanskincare',
#  7: 'restoring strengthening skin',
#  8: 'youthfulskin antiaging',
#  9: 'sensitiveskin skincare',
#  10: 'skincare sunscreen',
#  11: 'keeping skin healthy',
#  12: 'science ceramides skincare',
#  13: 'skincareroutine',
#  14: 'skincare preppygrwm',
#  15: 'skincare restoring',
#  16: 'ersas skin care',
#  17: 'skin barrier repair',
#  18: 'purify detoxify skin',
#  19: 'skincare whitening'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2    31540  Exercises For Chubby Face || Anti aging Face M...
# 3    49358            summer skin toner //home tips by soniya
# 4    31561  5 Mins Face Massage to look 10 years younger/F...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Did you know that you can slow down ageing and...
# 2  Exercises For Chubby Face || Anti aging Face M...
# 3                                     no description
# 4  hello viewers\n          I am sharing a face m...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['be beautiful', 'be beautiful skincare', 'ant...
# 2  ['exercises for chubby face', 'excercise for d...
# 3                                                 []
# 4  ['#fabsana', '#antiagingfacemassage', '#skinti...
#
#                                           clean_text             keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...         [anti aging]
# 1  anti ageing massage routine for a wrinkle free...         [anti aging]
# 2  exercises for chubby face anti aging face mass...         [anti aging]
# 3  summer skin toner home tips by soniya no descr...  [skin care routine]
# 4  5 mins face massage to look 10 years younger f...         [anti aging]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Skincare & Anti-Aging             0.588283       8204        368
# 1  Skincare & Anti-Aging             0.588283       4502        170
# 2  Skincare & Anti-Aging             0.588283        117          8
# 3  Skincare & Anti-Aging             0.682736         41          3
# 4  Skincare & Anti-Aging             0.588283        110          7
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0            27         0.048147  104589.08836  2484.359585     21.462159
# 1            16         0.041315  104589.08836  2484.359585     21.462159
# 2             1         0.076923  104589.08836  2484.359585     21.462159
# 3             1         0.097561  104589.08836  2484.359585     21.462159
# 4             3         0.090909  104589.08836  2484.359585     21.462159
#
#    avg_engagement_rate       new_keywords
# 0             0.021585  [anti aging face]
# 1             0.021585  [anti aging face]
# 2             0.021585  [anti aging face]
# 3             0.021585    [skincare tips]
# 4             0.021585  [anti aging face]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2    31540  Exercises For Chubby Face || Anti aging Face M...
# 3    49358            summer skin toner //home tips by soniya
# 4    31561  5 Mins Face Massage to look 10 years younger/F...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Did you know that you can slow down ageing and...
# 2  Exercises For Chubby Face || Anti aging Face M...
# 3                                     no description
# 4  hello viewers\n          I am sharing a face m...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['be beautiful', 'be beautiful skincare', 'ant...
# 2  ['exercises for chubby face', 'excercise for d...
# 3                                                 []
# 4  ['#fabsana', '#antiagingfacemassage', '#skinti...
#
#                                           clean_text             keywords  \
# 0  anti ageing face yoga simple 5 steps have you ...         [anti aging]
# 1  anti ageing massage routine for a wrinkle free...         [anti aging]
# 2  exercises for chubby face anti aging face mass...         [anti aging]
# 3  summer skin toner home tips by soniya no descr...  [skin care routine]
# 4  5 mins face massage to look 10 years younger f...         [anti aging]
#
#                 category  category_confidence  viewCount  likeCount  \
# 0  Skincare & Anti-Aging             0.588283       8204        368
# 1  Skincare & Anti-Aging             0.588283       4502        170
# 2  Skincare & Anti-Aging             0.588283        117          8
# 3  Skincare & Anti-Aging             0.682736         41          3
# 4  Skincare & Anti-Aging             0.588283        110          7
#
#    commentCount  engagement_rate     avg_views    avg_likes  avg_comments  \
# 0            27         0.048147  104589.08836  2484.359585     21.462159
# 1            16         0.041315  104589.08836  2484.359585     21.462159
# 2             1         0.076923  104589.08836  2484.359585     21.462159
# 3             1         0.097561  104589.08836  2484.359585     21.462159
# 4             3         0.090909  104589.08836  2484.359585     21.462159
#
#    avg_engagement_rate       new_keywords
# 0             0.021585  [anti aging face]
# 1             0.021585  [anti aging face]
# 2             0.021585  [anti aging face]
# 3             0.021585    [skincare tips]
# 4             0.021585  [anti aging face]
# new_keywords
# anti aging face                    627
# skincareroutine                    527
# hydrated skin                      330
# skincare tips                      234
# skin barrier repair                185
# restoring strengthening skin       177
# solutions skin concerns            130
# keeping skin healthy                91
# skincare restoring                  51
# wrinkles antiaging                  43
# skincare sunscreen                  39
# skincare preppygrwm                 34
# sensitiveskin skincare              28
# unachilenaenuk woman skincare       28
# science ceramides skincare          17
# purify detoxify skin                15
# skincare whitening                  14
# skincare kbeauty koreanskincare     13
# ersas skin care                     12
# youthfulskin antiaging               8
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0    77988             Anti Ageing Face Yoga - Simple 5 steps
# 1    41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2    31540  Exercises For Chubby Face || Anti aging Face M...
# 3    49358            summer skin toner //home tips by soniya
# 4    31561  5 Mins Face Massage to look 10 years younger/F...
#
#                                          description  \
# 0  Have you tried doing face yoga and do you know...
# 1  Did you know that you can slow down ageing and...
# 2  Exercises For Chubby Face || Anti aging Face M...
# 3                                     no description
# 4  hello viewers\n          I am sharing a face m...
#
#                                                 tags  \
# 0  ['anti aging face yoga', 'face yoga for glowin...
# 1  ['be beautiful', 'be beautiful skincare', 'ant...
# 2  ['exercises for chubby face', 'excercise for d...
# 3                                                 []
# 4  ['#fabsana', '#antiagingfacemassage', '#skinti...
#
#                                           clean_text               category  \
# 0  anti ageing face yoga simple 5 steps have you ...  Skincare & Anti-Aging
# 1  anti ageing massage routine for a wrinkle free...  Skincare & Anti-Aging
# 2  exercises for chubby face anti aging face mass...  Skincare & Anti-Aging
# 3  summer skin toner home tips by soniya no descr...  Skincare & Anti-Aging
# 4  5 mins face massage to look 10 years younger f...  Skincare & Anti-Aging
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.588283       8204        368            27         0.048147
# 1             0.588283       4502        170            16         0.041315
# 2             0.588283        117          8             1         0.076923
# 3             0.682736         41          3             1         0.097561
# 4             0.588283        110          7             3         0.090909
#
#       avg_views    avg_likes  avg_comments  avg_engagement_rate  \
# 0  104589.08836  2484.359585     21.462159             0.021585
# 1  104589.08836  2484.359585     21.462159             0.021585
# 2  104589.08836  2484.359585     21.462159             0.021585
# 3  104589.08836  2484.359585     21.462159             0.021585
# 4  104589.08836  2484.359585     21.462159             0.021585
#
#           keywords
# 0  anti aging face
# 1  anti aging face
# 2  anti aging face
# 3    skincare tips
# 4  anti aging face

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0     77988             Anti Ageing Face Yoga - Simple 5 steps
# 1     41278  Anti Ageing Massage Routine For A Wrinkle Free...
# 2     31540  Exercises For Chubby Face || Anti aging Face M...
# 3     49358            summer skin toner //home tips by soniya
# 4     31561  5 Mins Face Massage to look 10 years younger/F...
# 5     20702         Mature Skin Tips for Seint IIID Foundation
# 6     70725   Anti Ageing Face Yoga : Face Yoga For Fine Lines
# 7     57088  Anti Ageing Secrete Make Up Tips || Anti Aging...
# 8     48168  Extremely Long Lasting Waterproof Makeup Like ...
# 9      3235  Kurta Pyjama Kala Kala- 1 Black Kurta 2 Styles...
# 10    75978  FACIAL AT HOME... STEP BY STEP USING DERMACOS ...
# 11    56116  smooth and clean skin after face shaving hundr...
# 12    58402  #SHORT #SHORTS #VLCC #SALON #BEAUTY #HAIR #MAK...
# 13    11116  #shorts Essential face 🙎‍♀️ #serums #Nybae #Go...
# 14    43430  Duque_Formative Assessment 5_ Preferring light...
# 15    61733  wow look at the transformation @kylefossum_ #s...
# 16    16156         ❤️✨skin care routine ❤️✨ by )angel Sabana)
# 17    35324  बिना पैसे खर्च किये 50 की उम्र में 30 के दिखोग...
# 18    79409  The secret of young Japanese women !! Anti-agi...
# 19    72551        #shorts Beauty Glazed colourboard Eyeshadow
#
#                                           description  \
# 0   Have you tried doing face yoga and do you know...
# 1   Did you know that you can slow down ageing and...
# 2   Exercises For Chubby Face || Anti aging Face M...
# 3                                      no description
# 4   hello viewers\n          I am sharing a face m...
# 5                                      no description
# 6   Face yoga forfine lines and anti ageing \n\nFo...
# 7   After 30+ Anti Ageing And Wrinkles Is Major Pr...
# 8   Hi! I am Manisha from Kolkata,India. I am a ve...
# 9                                      no description
# 10  Made with Film Maker\nhttps://play.google.com/...
# 11                                     no description
# 12                                     no description
# 13                                     no description
# 14                                     no description
# 15                                     no description
# 16                                     no description
# 17  Do some face exercises and look 20 years young...
# 18  Hello Every Body My Video Show About: Traditio...
# 19                 #shorts\n\nBeauty glazed eyeshadow
#
#                                                  tags  \
# 0   ['anti aging face yoga', 'face yoga for glowin...
# 1   ['be beautiful', 'be beautiful skincare', 'ant...
# 2   ['exercises for chubby face', 'excercise for d...
# 3                                                  []
# 4   ['#fabsana', '#antiagingfacemassage', '#skinti...
# 5                                                  []
# 6                                                  []
# 7   ['Anti Ageing Secrete Make Up Tips', 'Anti Agi...
# 8                                                  []
# 9                                                  []
# 10  ['Film Maker Pro', 'DERMACOS', 'Dermacosmetics...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17  ['face exercise', 'face exercises', 'look youn...
# 18                                                 []
# 19                                                 []
#
#                                            clean_text               category  \
# 0   anti ageing face yoga simple 5 steps have you ...  Skincare & Anti-Aging
# 1   anti ageing massage routine for a wrinkle free...  Skincare & Anti-Aging
# 2   exercises for chubby face anti aging face mass...  Skincare & Anti-Aging
# 3   summer skin toner home tips by soniya no descr...  Skincare & Anti-Aging
# 4   5 mins face massage to look 10 years younger f...  Skincare & Anti-Aging
# 5   mature skin tips for seint iiid foundation no ...  Skincare & Anti-Aging
# 6   anti ageing face yoga face yoga for fine lines...  Skincare & Anti-Aging
# 7   anti ageing secrete make up tips anti aging ma...  Skincare & Anti-Aging
# 8   extremely long lasting waterproof makeup like ...  Skincare & Anti-Aging
# 9   kurta pyjama kala kala 1 black kurta 2 styles ...  Skincare & Anti-Aging
# 10  facial at home step by step using dermacos pro...  Skincare & Anti-Aging
# 11  smooth and clean skin after face shaving hundr...  Skincare & Anti-Aging
# 12  #short #shorts #vlcc #salon #beauty #hair #mak...  Skincare & Anti-Aging
# 13  #shorts essential face #serums #nybae #goodvib...  Skincare & Anti-Aging
# 14  duque formative assessment 5 preferring light ...  Skincare & Anti-Aging
# 15  wow look at the transformation kylefossum #sho...  Skincare & Anti-Aging
# 16   skin care routine by angel sabana no description  Skincare & Anti-Aging
# 17  50 30 anti aging face exercises in hindi face ...  Skincare & Anti-Aging
# 18  the secret of young japanese women anti aging ...  Skincare & Anti-Aging
# 19  #shorts beauty glazed colourboard eyeshadow #s...  Skincare & Anti-Aging
#
#     category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0              0.588283       8204        368            27         0.048147
# 1              0.588283       4502        170            16         0.041315
# 2              0.588283        117          8             1         0.076923
# 3              0.682736         41          3             1         0.097561
# 4              0.588283        110          7             3         0.090909
# 5              0.682736       3081         40             0         0.012983
# 6              0.571597        225         21             4         0.111111
# 7              0.588283         56          3             2         0.089286
# 8              0.571597       3427         79            21         0.029180
# 9              0.631715       1837         49             0         0.026674
# 10             0.571597        479         14             1         0.031315
# 11             0.682736       2640         46             2         0.018182
# 12             0.631715        771         58             1         0.076524
# 13             0.631715       1285         50             0         0.038911
# 14             0.682736         17          3             0         0.176471
# 15             0.631715       3631        109             2         0.030570
# 16             0.682736        679         23             1         0.035346
# 17             0.588283         32          1             0         0.031250
# 18             0.588283        410         16             0         0.039024
# 19             0.631715         33          3             1         0.121212
#
#        avg_views    avg_likes  avg_comments  avg_engagement_rate  \
# 0   104589.08836  2484.359585     21.462159             0.021585
# 1   104589.08836  2484.359585     21.462159             0.021585
# 2   104589.08836  2484.359585     21.462159             0.021585
# 3   104589.08836  2484.359585     21.462159             0.021585
# 4   104589.08836  2484.359585     21.462159             0.021585
# 5   104589.08836  2484.359585     21.462159             0.021585
# 6   104589.08836  2484.359585     21.462159             0.021585
# 7   104589.08836  2484.359585     21.462159             0.021585
# 8   104589.08836  2484.359585     21.462159             0.021585
# 9   104589.08836  2484.359585     21.462159             0.021585
# 10  104589.08836  2484.359585     21.462159             0.021585
# 11  104589.08836  2484.359585     21.462159             0.021585
# 12  104589.08836  2484.359585     21.462159             0.021585
# 13  104589.08836  2484.359585     21.462159             0.021585
# 14  104589.08836  2484.359585     21.462159             0.021585
# 15  104589.08836  2484.359585     21.462159             0.021585
# 16  104589.08836  2484.359585     21.462159             0.021585
# 17  104589.08836  2484.359585     21.462159             0.021585
# 18  104589.08836  2484.359585     21.462159             0.021585
# 19  104589.08836  2484.359585     21.462159             0.021585
#
#            keywords                publishedAt
# 0   anti aging face  2021-03-15 09:30:02+00:00
# 1   anti aging face  2021-03-17 15:01:12+00:00
# 2   anti aging face  2021-03-21 13:53:34+00:00
# 3     skincare tips  2021-03-24 06:09:07+00:00
# 4   anti aging face  2021-03-26 05:22:36+00:00
# 5     skincare tips  2021-03-26 23:19:09+00:00
# 6   ersas skin care  2021-03-29 09:33:06+00:00
# 7   anti aging face  2021-04-02 05:25:14+00:00
# 8   ersas skin care  2021-04-02 15:01:39+00:00
# 9   skincareroutine  2021-04-03 15:18:09+00:00
# 10  ersas skin care  2021-04-04 01:42:14+00:00
# 11    skincare tips  2021-04-04 10:01:25+00:00
# 12  skincareroutine  2021-04-06 15:59:14+00:00
# 13  skincareroutine  2021-04-07 10:29:35+00:00
# 14    skincare tips  2021-04-08 09:53:52+00:00
# 15  skincareroutine  2021-04-09 13:53:47+00:00
# 16    skincare tips  2021-04-09 15:04:24+00:00
# 17  anti aging face  2021-04-10 13:46:54+00:00
# 18  anti aging face  2021-04-10 14:04:01+00:00
# 19  skincareroutine  2021-04-11 19:31:19+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#                keyword  velocity  engagement_rate    phase
#     skincare whitening       8.0         0.018689 Emerging
# sensitiveskin skincare       5.0         0.009644 Emerging
#   purify detoxify skin       1.0         0.010763 Emerging
#
# 🔝 Top 10 Growing keywords:
#                keyword  velocity  engagement_rate   phase
#        ersas skin care       0.5         0.113839 Growing
# youthfulskin antiaging       0.5         0.022152 Growing
#
# 🔝 Top 10 Peaking keywords:
#                         keyword      velocity  engagement_rate   phase
#                   skincare tips -5.500000e+00         0.044924 Peaking
#                 skincareroutine -2.141562e-14         0.039493 Peaking
#             skincare preppygrwm -2.500000e+00         0.035384 Peaking
#                 anti aging face -1.150000e+01         0.034124 Peaking
#              wrinkles antiaging -1.500000e+00         0.026673 Peaking
#   unachilenaenuk woman skincare -2.000000e+00         0.023039 Peaking
#              skincare sunscreen -4.500000e+00         0.020601 Peaking
# skincare kbeauty koreanskincare -1.500000e+00         0.020601 Peaking
#
# 🔝 Top 10 Decaying keywords:
#                      keyword  velocity  engagement_rate    phase
#                hydrated skin     -77.5         0.015141 Decaying
# restoring strengthening skin     -37.0         0.011115 Decaying
#          skin barrier repair     -32.0         0.020316 Decaying
#         keeping skin healthy     -26.0         0.014579 Decaying
#      solutions skin concerns     -16.0         0.010386 Decaying
#           skincare restoring     -13.0         0.009666 Decaying
#   science ceramides skincare       0.0         0.008774 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("Skincare_and_Anti-Aging_keyword_trend_phases.csv", index=False)
print("✅ Saved to Skincare_and_Anti-Aging_keyword_trend_phases.csv")
# Out:
# ✅ Saved to Skincare_and_Anti-Aging_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#                 keyword  velocity  engagement_rate     phase
# 0       anti aging face     -11.5         0.034124   Peaking
# 1       ersas skin care       0.5         0.113839   Growing
# 2         hydrated skin     -77.5         0.015141  Decaying
# 3  keeping skin healthy     -26.0         0.014579  Decaying
# 4  purify detoxify skin       1.0         0.010763  Emerging

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Peaking      8
# 1  Decaying      7
# 2  Emerging      3
# 3   Growing      2
