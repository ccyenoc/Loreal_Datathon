# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Vlogs_and_Lifestyle.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0    23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1    48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2    51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3    36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4    44931  haircut and hairstyling #hairsmoothing #hairst...
#
#                                          description  \
# 0  #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1  Please subscribe video acchi Lage to like karn...
# 2  #shorts #greyhair #ombre #brushlight #doityour...
# 3  Amazing hair transformations you won't believe...
# 4               thank you for watching this video🎥..
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                            ['dıy', 'doityourself']
# 3                                                 []
# 4  ['haircut', 'hairsmoothening', 'hairsmoothenin...
#
#                                           clean_text keywords  \
# 0  raksha bandhan makeup look no foundation rakhi...     vlog
# 1  md #nadeem#jawed# habib#blow #dryer please sub...     vlog
# 2  hair style ombre do it yourself limond #shorts...     vlog
# 3  amazing hair transformations you won #39 t bel...     vlog
# 4  haircut and hairstyling #hairsmoothing #hairst...     vlog
#
#             category  category_confidence  viewCount  likeCount  commentCount  \
# 0  Vlogs & Lifestyle             0.747283       2567        103             2
# 1  Vlogs & Lifestyle             0.747283        307         54             5
# 2  Vlogs & Lifestyle             0.747283        639         17             0
# 3  Vlogs & Lifestyle             0.747283    8060040     134201          4878
# 4  Vlogs & Lifestyle             0.747283        482         12             0
#
#    engagement_rate    avg_views     avg_likes  avg_comments  \
# 0         0.040904  514283.5625  13623.928571       147.125
# 1         0.192182  514283.5625  13623.928571       147.125
# 2         0.026604  514283.5625  13623.928571       147.125
# 3         0.017255  514283.5625  13623.928571       147.125
# 4         0.024896  514283.5625  13623.928571       147.125
#
#    avg_engagement_rate
# 0             0.033626
# 1             0.033626
# 2             0.033626
# 3             0.033626
# 4             0.033626

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Vlogs_and_Lifestyle.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0    23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1    48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2    51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3    36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4    44931  haircut and hairstyling #hairsmoothing #hairst...
#
#                                          description  \
# 0  #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1  Please subscribe video acchi Lage to like karn...
# 2  #shorts #greyhair #ombre #brushlight #doityour...
# 3  Amazing hair transformations you won't believe...
# 4               thank you for watching this video🎥..
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                            ['dıy', 'doityourself']
# 3                                                 []
# 4  ['haircut', 'hairsmoothening', 'hairsmoothenin...
#
#                                           clean_text keywords  \
# 0  raksha bandhan makeup look no foundation rakhi...   [vlog]
# 1  md #nadeem#jawed# habib#blow #dryer please sub...   [vlog]
# 2  hair style ombre do it yourself limond #shorts...   [vlog]
# 3  amazing hair transformations you won #39 t bel...   [vlog]
# 4  haircut and hairstyling #hairsmoothing #hairst...   [vlog]
#
#             category  category_confidence  viewCount  likeCount  commentCount  \
# 0  Vlogs & Lifestyle             0.747283       2567        103             2
# 1  Vlogs & Lifestyle             0.747283        307         54             5
# 2  Vlogs & Lifestyle             0.747283        639         17             0
# 3  Vlogs & Lifestyle             0.747283    8060040     134201          4878
# 4  Vlogs & Lifestyle             0.747283        482         12             0
#
#    engagement_rate    avg_views     avg_likes  avg_comments  \
# 0         0.040904  514283.5625  13623.928571       147.125
# 1         0.192182  514283.5625  13623.928571       147.125
# 2         0.026604  514283.5625  13623.928571       147.125
# 3         0.017255  514283.5625  13623.928571       147.125
# 4         0.024896  514283.5625  13623.928571       147.125
#
#    avg_engagement_rate
# 0             0.033626
# 1             0.033626
# 2             0.033626
# 3             0.033626
# 4             0.033626

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
#              keyword                                          embedding
# 0               vlog  [0.03960747, -0.014355414, -0.02090624, -0.020...
# 1          lifestyle  [-0.017576318, 0.040363044, 0.004310447, 0.089...
# 2           minivlog  [0.051772404, 0.027090685, 0.009536912, -0.033...
# 3        vlogs neetu  [-0.03237997, -0.01836234, -0.039542273, -0.01...
# 4  vlogs neetu bisht  [-0.026792632, 0.061746057, -0.033039667, -0.0...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#              keyword                                          embedding  \
# 0               vlog  [0.03960747, -0.014355414, -0.02090624, -0.020...
# 1          lifestyle  [-0.017576318, 0.040363044, 0.004310447, 0.089...
# 2           minivlog  [0.051772404, 0.027090685, 0.009536912, -0.033...
# 3        vlogs neetu  [-0.03237997, -0.01836234, -0.039542273, -0.01...
# 4  vlogs neetu bisht  [-0.026792632, 0.061746057, -0.033039667, -0.0...
#
#    cluster_label
# 0              2
# 1              0
# 2              3
# 3              1
# 4              1

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'lifestyle', 1: 'vlogs neetu bisht', 2: 'vlog', 3: 'minivlog'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0    23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1    48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2    51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3    36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4    44931  haircut and hairstyling #hairsmoothing #hairst...
#
#                                          description  \
# 0  #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1  Please subscribe video acchi Lage to like karn...
# 2  #shorts #greyhair #ombre #brushlight #doityour...
# 3  Amazing hair transformations you won't believe...
# 4               thank you for watching this video🎥..
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                            ['dıy', 'doityourself']
# 3                                                 []
# 4  ['haircut', 'hairsmoothening', 'hairsmoothenin...
#
#                                           clean_text keywords  \
# 0  raksha bandhan makeup look no foundation rakhi...   [vlog]
# 1  md #nadeem#jawed# habib#blow #dryer please sub...   [vlog]
# 2  hair style ombre do it yourself limond #shorts...   [vlog]
# 3  amazing hair transformations you won #39 t bel...   [vlog]
# 4  haircut and hairstyling #hairsmoothing #hairst...   [vlog]
#
#             category  category_confidence  viewCount  likeCount  commentCount  \
# 0  Vlogs & Lifestyle             0.747283       2567        103             2
# 1  Vlogs & Lifestyle             0.747283        307         54             5
# 2  Vlogs & Lifestyle             0.747283        639         17             0
# 3  Vlogs & Lifestyle             0.747283    8060040     134201          4878
# 4  Vlogs & Lifestyle             0.747283        482         12             0
#
#    engagement_rate    avg_views     avg_likes  avg_comments  \
# 0         0.040904  514283.5625  13623.928571       147.125
# 1         0.192182  514283.5625  13623.928571       147.125
# 2         0.026604  514283.5625  13623.928571       147.125
# 3         0.017255  514283.5625  13623.928571       147.125
# 4         0.024896  514283.5625  13623.928571       147.125
#
#    avg_engagement_rate new_keywords
# 0             0.033626       [vlog]
# 1             0.033626       [vlog]
# 2             0.033626       [vlog]
# 3             0.033626       [vlog]
# 4             0.033626       [vlog]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0    23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1    48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2    51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3    36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4    44931  haircut and hairstyling #hairsmoothing #hairst...
#
#                                          description  \
# 0  #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1  Please subscribe video acchi Lage to like karn...
# 2  #shorts #greyhair #ombre #brushlight #doityour...
# 3  Amazing hair transformations you won't believe...
# 4               thank you for watching this video🎥..
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                            ['dıy', 'doityourself']
# 3                                                 []
# 4  ['haircut', 'hairsmoothening', 'hairsmoothenin...
#
#                                           clean_text keywords  \
# 0  raksha bandhan makeup look no foundation rakhi...   [vlog]
# 1  md #nadeem#jawed# habib#blow #dryer please sub...   [vlog]
# 2  hair style ombre do it yourself limond #shorts...   [vlog]
# 3  amazing hair transformations you won #39 t bel...   [vlog]
# 4  haircut and hairstyling #hairsmoothing #hairst...   [vlog]
#
#             category  category_confidence  viewCount  likeCount  commentCount  \
# 0  Vlogs & Lifestyle             0.747283       2567        103             2
# 1  Vlogs & Lifestyle             0.747283        307         54             5
# 2  Vlogs & Lifestyle             0.747283        639         17             0
# 3  Vlogs & Lifestyle             0.747283    8060040     134201          4878
# 4  Vlogs & Lifestyle             0.747283        482         12             0
#
#    engagement_rate    avg_views     avg_likes  avg_comments  \
# 0         0.040904  514283.5625  13623.928571       147.125
# 1         0.192182  514283.5625  13623.928571       147.125
# 2         0.026604  514283.5625  13623.928571       147.125
# 3         0.017255  514283.5625  13623.928571       147.125
# 4         0.024896  514283.5625  13623.928571       147.125
#
#    avg_engagement_rate new_keywords
# 0             0.033626       [vlog]
# 1             0.033626       [vlog]
# 2             0.033626       [vlog]
# 3             0.033626       [vlog]
# 4             0.033626       [vlog]
# new_keywords
# vlog                 65
# lifestyle            27
# vlogs neetu bisht    14
# minivlog              6
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0    23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1    48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2    51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3    36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4    44931  haircut and hairstyling #hairsmoothing #hairst...
#
#                                          description  \
# 0  #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1  Please subscribe video acchi Lage to like karn...
# 2  #shorts #greyhair #ombre #brushlight #doityour...
# 3  Amazing hair transformations you won't believe...
# 4               thank you for watching this video🎥..
#
#                                                 tags  \
# 0                                                 []
# 1                                                 []
# 2                            ['dıy', 'doityourself']
# 3                                                 []
# 4  ['haircut', 'hairsmoothening', 'hairsmoothenin...
#
#                                           clean_text           category  \
# 0  raksha bandhan makeup look no foundation rakhi...  Vlogs & Lifestyle
# 1  md #nadeem#jawed# habib#blow #dryer please sub...  Vlogs & Lifestyle
# 2  hair style ombre do it yourself limond #shorts...  Vlogs & Lifestyle
# 3  amazing hair transformations you won #39 t bel...  Vlogs & Lifestyle
# 4  haircut and hairstyling #hairsmoothing #hairst...  Vlogs & Lifestyle
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.747283       2567        103             2         0.040904
# 1             0.747283        307         54             5         0.192182
# 2             0.747283        639         17             0         0.026604
# 3             0.747283    8060040     134201          4878         0.017255
# 4             0.747283        482         12             0         0.024896
#
#      avg_views     avg_likes  avg_comments  avg_engagement_rate keywords
# 0  514283.5625  13623.928571       147.125             0.033626     vlog
# 1  514283.5625  13623.928571       147.125             0.033626     vlog
# 2  514283.5625  13623.928571       147.125             0.033626     vlog
# 3  514283.5625  13623.928571       147.125             0.033626     vlog
# 4  514283.5625  13623.928571       147.125             0.033626     vlog

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0     23365  Raksha Bandhan Makeup Look || No Foundation Ra...
# 1     48957                MD #Nadeem#Jawed# Habib#blow #dryer
# 2     51510  Hair Style | Ombre | do it yourself 💎LimonD #s...
# 3     36725  Amazing Hair Transformations You Won&#39;t Bel...
# 4     44931  haircut and hairstyling #hairsmoothing #hairst...
# 5     68625  Nora fatehi inspired makeup look || Power Blus...
# 6     75366                                         hair hacks
# 7     14685  old Man Amazing #Beard_Fashion style 2021 and ...
# 8     37280  ####❤️❤️❤️Indian Bridal Long Lasting Summer Ma...
# 9     88809  Cute Different Ways To Style Bangs | Short Hai...
# 10    22567                #Jafra Cream blush Peach,kereeeen❤️
# 11    50567  amazing hair pony style👌👌 trick#shorts #beauty...
# 12    23787  subscribe to watch full video #hairstyles #sho...
# 13    37376  amazing hair style 👌#hair #vlog #beauty #insta...
# 14    15665       Diya Aur Baati hum Makeup challenge☺️#shorts
# 15    72674  #shaziyastyle #shorts #ytshorts #hack  lip lin...
# 16    69768        Pomade vs Styling Cream | Mens Hair #shorts
# 17    86270  EASY Curtain Hairstyle with Sea Salt Spray | M...
# 18    11570  Best Face Mask Tutorial | Men&#39;s Skin Care ...
# 19    43236  How to Style Fringe Hairstyle | Men’s Hair #sh...
#
#                                           description  \
# 0   #anshupriya #ytshorts #youtubeshorts #newytsho...
# 1   Please subscribe video acchi Lage to like karn...
# 2   #shorts #greyhair #ombre #brushlight #doityour...
# 3   Amazing hair transformations you won't believe...
# 4                thank you for watching this video🎥..
# 5   pls subscribe if u like🥰🥰🥰\n\n\n\n\n#shorts\n#...
# 6   #beautiful ,#mylove ,#america ,#china ,#basket...
# 7   old Man Amazing #Beard_Fashion_style 2021 and ...
# 8   Indian Bridal Makeup by Aarati Shaw.\nHello ev...
# 9   #hairstyles #shorthair #bangs #tomboy #tombrai...
# 10  Saya menggunakan produk cream blush Peach by J...
# 11  @ruchi_and_amit@RuchiandPiyush @radhikarealvlo...
# 12                     music credits: Joy by Ashutosh
# 13  @RuchiandPiyush@ayanmomandbeauty9721 @naturalp...
# 14  #shorts \n#makeup \n#makeupgiveshappiness \n#m...
# 15                                     no description
# 16  Pomade vs Styling Cream | Mens Hair #shorts\n\...
# 17  EASY Curtain Hairstyle with Sea Salt Spray | M...
# 18  Best Face Mask Tutorial | Men's Skin Care Rout...
# 19  How to Style Fringe Hairstyle | Men’s Hair #sh...
#
#                                                  tags  \
# 0                                                  []
# 1                                                  []
# 2                             ['dıy', 'doityourself']
# 3                                                  []
# 4   ['haircut', 'hairsmoothening', 'hairsmoothenin...
# 5                ['nora fatehi inspired makeup look']
# 6   ['#viral', '#fyp', '#foryou', '#youtube', '#yo...
# 7                                                  []
# 8                                                  []
# 9   ['short hair', 'bangs', 'ulzzang girl', 'tombo...
# 10                                                 []
# 11                                                 []
# 12  ['hairstyles', 'cute hairstyles', 'easy hairst...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  ['mens hair', 'hairstyle', 'pomade', 'mens hai...
# 17  ['mens hair', 'hairstyle', 'pomade', 'mens hai...
# 18  ['skincare routine', 'skincare', 'skin care', ...
# 19                                                 []
#
#                                            clean_text           category  \
# 0   raksha bandhan makeup look no foundation rakhi...  Vlogs & Lifestyle
# 1   md #nadeem#jawed# habib#blow #dryer please sub...  Vlogs & Lifestyle
# 2   hair style ombre do it yourself limond #shorts...  Vlogs & Lifestyle
# 3   amazing hair transformations you won #39 t bel...  Vlogs & Lifestyle
# 4   haircut and hairstyling #hairsmoothing #hairst...  Vlogs & Lifestyle
# 5   nora fatehi inspired makeup look power blush #...  Vlogs & Lifestyle
# 6   hair hacks #beautiful #mylove #america #china ...  Vlogs & Lifestyle
# 7   old man amazing #beard fashion style 2021 and ...  Vlogs & Lifestyle
# 8   #### indian bridal long lasting summer makeup ...  Vlogs & Lifestyle
# 9   cute different ways to style bangs short hair ...  Vlogs & Lifestyle
# 10  #jafra cream blush peach kereeeen saya menggun...  Vlogs & Lifestyle
# 11  amazing hair pony style trick#shorts #beauty #...  Vlogs & Lifestyle
# 12  subscribe to watch full video #hairstyles #sho...  Vlogs & Lifestyle
# 13  amazing hair style #hair #vlog #beauty #instag...  Vlogs & Lifestyle
# 14  diya aur baati hum makeup challenge #shorts #s...  Vlogs & Lifestyle
# 15  #shaziyastyle #shorts #ytshorts #hack lip line...  Vlogs & Lifestyle
# 16  pomade vs styling cream mens hair #shorts poma...  Vlogs & Lifestyle
# 17  easy curtain hairstyle with sea salt spray men...  Vlogs & Lifestyle
# 18  best face mask tutorial men #39 s skin care ro...  Vlogs & Lifestyle
# 19  how to style fringe hairstyle men s hair #shor...  Vlogs & Lifestyle
#
#     category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0              0.747283       2567        103             2         0.040904
# 1              0.747283        307         54             5         0.192182
# 2              0.747283        639         17             0         0.026604
# 3              0.747283    8060040     134201          4878         0.017255
# 4              0.747283        482         12             0         0.024896
# 5              0.747283        842         57            12         0.081948
# 6              0.747283        755         32             0         0.042384
# 7              0.747283        232         11             2         0.056034
# 8              0.747283        117         18             5         0.196581
# 9              0.747283    4581941     203944          1266         0.044787
# 10             0.747283        100         13             2         0.150000
# 11             0.747283        563         17             3         0.035524
# 12             0.747283        481         16             1         0.035343
# 13             0.747283       1197         24             7         0.025898
# 14             0.747283      90190       5120            75         0.057601
# 15             0.747283       1740         35             0         0.020115
# 16             0.585129     682095      17065           138         0.025221
# 17             0.585129      93625       2911            44         0.031562
# 18             0.585129      48009       1124            10         0.023621
# 19             0.585129     663076      13734            71         0.020820
#
#       avg_views     avg_likes  avg_comments  avg_engagement_rate   keywords  \
# 0   514283.5625  13623.928571       147.125             0.033626       vlog
# 1   514283.5625  13623.928571       147.125             0.033626       vlog
# 2   514283.5625  13623.928571       147.125             0.033626       vlog
# 3   514283.5625  13623.928571       147.125             0.033626       vlog
# 4   514283.5625  13623.928571       147.125             0.033626       vlog
# 5   514283.5625  13623.928571       147.125             0.033626       vlog
# 6   514283.5625  13623.928571       147.125             0.033626       vlog
# 7   514283.5625  13623.928571       147.125             0.033626       vlog
# 8   514283.5625  13623.928571       147.125             0.033626       vlog
# 9   514283.5625  13623.928571       147.125             0.033626       vlog
# 10  514283.5625  13623.928571       147.125             0.033626       vlog
# 11  514283.5625  13623.928571       147.125             0.033626       vlog
# 12  514283.5625  13623.928571       147.125             0.033626       vlog
# 13  514283.5625  13623.928571       147.125             0.033626       vlog
# 14  514283.5625  13623.928571       147.125             0.033626       vlog
# 15  514283.5625  13623.928571       147.125             0.033626       vlog
# 16  514283.5625  13623.928571       147.125             0.033626  lifestyle
# 17  514283.5625  13623.928571       147.125             0.033626  lifestyle
# 18  514283.5625  13623.928571       147.125             0.033626  lifestyle
# 19  514283.5625  13623.928571       147.125             0.033626  lifestyle
#
#                   publishedAt
# 0   2021-08-21 05:48:45+00:00
# 1   2021-08-23 04:02:32+00:00
# 2   2021-09-03 00:15:38+00:00
# 3   2021-09-10 18:36:03+00:00
# 4   2021-09-11 01:58:11+00:00
# 5   2021-09-17 03:54:51+00:00
# 6   2021-09-22 04:16:53+00:00
# 7   2021-10-05 07:28:46+00:00
# 8   2021-10-15 12:59:30+00:00
# 9   2021-10-15 13:17:45+00:00
# 10  2021-10-16 10:24:59+00:00
# 11  2021-10-26 05:29:58+00:00
# 12  2021-11-04 16:21:54+00:00
# 13  2021-11-05 12:40:30+00:00
# 14  2021-11-19 03:42:09+00:00
# 15  2022-06-14 14:43:58+00:00
# 16  2022-06-26 15:34:19+00:00
# 17  2022-07-09 15:29:25+00:00
# 18  2022-07-12 13:30:01+00:00
# 19  2022-07-30 14:28:33+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#   keyword  velocity  engagement_rate    phase
# lifestyle       0.5         0.021934 Emerging
#
# 🔝 Top 10 Growing keywords:
#  keyword  velocity  engagement_rate   phase
#     vlog       2.5         0.041694 Growing
# minivlog       0.5         0.050803 Growing
#
# 🔝 Top 10 Peaking keywords:
# Empty DataFrame
# Columns: [keyword, velocity, engagement_rate, phase]
# Index: []
#
# 🔝 Top 10 Decaying keywords:
#           keyword  velocity  engagement_rate    phase
# vlogs neetu bisht     -10.0         0.019767 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("Vlogs_and_Lifestyle_keyword_trend_phases.csv", index=False)
print("✅ Saved to Vlogs_and_Lifestyle_keyword_trend_phases.csv")
# Out:
# ✅ Saved to Vlogs_and_Lifestyle_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#              keyword  velocity  engagement_rate     phase
# 0          lifestyle       0.5         0.021934  Emerging
# 1           minivlog       0.5         0.050803   Growing
# 2               vlog       2.5         0.041694   Growing
# 3  vlogs neetu bisht     -10.0         0.019767  Decaying

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Growing      2
# 1  Emerging      1
# 2  Decaying      1
