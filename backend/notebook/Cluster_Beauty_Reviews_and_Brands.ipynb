# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Beauty_Reviews_and_Brands.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      537              Transformation hair colour correction
# 2    25429                        Huda Beauty UK London Event
# 3    26244  The Jersey Beauty guide to using Dermalogica e...
# 4    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  Helping clients achieve there hair goals. \nco...
# 2  We worked with the HUDA Beauty UK team to film...
# 3  In this video, Jen from Jersey Beauty chats to...
# 4                                     no description
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                 []
# 2  ['huda beauty', 'huda london', 'huda london ev...
# 3  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                 []
#
#                                           clean_text   keywords  \
# 0  five best anti ageing facial exercises look yo...  instagram
# 1  transformation hair colour correction helping ...  instagram
# 2  huda beauty uk london event we worked with the...  instagram
# 3  the jersey beauty guide to using dermalogica e...  instagram
# 4  tone n glow face wash for crystal clear skin n...  instagram
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Beauty Reviews & Brands             0.591229        161          4
# 1  Beauty Reviews & Brands             0.591229         83          2
# 2  Beauty Reviews & Brands             0.591229        121          3
# 3  Beauty Reviews & Brands             0.591229       2228         28
# 4  Beauty Reviews & Brands             0.591229      25959        341
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             1         0.031056  219357.518293  4787.326665     59.469033
# 1             0         0.024096  219357.518293  4787.326665     59.469033
# 2             1         0.033058  219357.518293  4787.326665     59.469033
# 3             0         0.012567  219357.518293  4787.326665     59.469033
# 4           166         0.019531  219357.518293  4787.326665     59.469033
#
#    avg_engagement_rate
# 0              0.04542
# 1              0.04542
# 2              0.04542
# 3              0.04542
# 4              0.04542

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Beauty_Reviews_and_Brands.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      537              Transformation hair colour correction
# 2    25429                        Huda Beauty UK London Event
# 3    26244  The Jersey Beauty guide to using Dermalogica e...
# 4    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  Helping clients achieve there hair goals. \nco...
# 2  We worked with the HUDA Beauty UK team to film...
# 3  In this video, Jen from Jersey Beauty chats to...
# 4                                     no description
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                 []
# 2  ['huda beauty', 'huda london', 'huda london ev...
# 3  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                 []
#
#                                           clean_text     keywords  \
# 0  five best anti ageing facial exercises look yo...  [instagram]
# 1  transformation hair colour correction helping ...  [instagram]
# 2  huda beauty uk london event we worked with the...  [instagram]
# 3  the jersey beauty guide to using dermalogica e...  [instagram]
# 4  tone n glow face wash for crystal clear skin n...  [instagram]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Beauty Reviews & Brands             0.591229        161          4
# 1  Beauty Reviews & Brands             0.591229         83          2
# 2  Beauty Reviews & Brands             0.591229        121          3
# 3  Beauty Reviews & Brands             0.591229       2228         28
# 4  Beauty Reviews & Brands             0.591229      25959        341
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             1         0.031056  219357.518293  4787.326665     59.469033
# 1             0         0.024096  219357.518293  4787.326665     59.469033
# 2             1         0.033058  219357.518293  4787.326665     59.469033
# 3             0         0.012567  219357.518293  4787.326665     59.469033
# 4           166         0.019531  219357.518293  4787.326665     59.469033
#
#    avg_engagement_rate
# 0              0.04542
# 1              0.04542
# 2              0.04542
# 3              0.04542
# 4              0.04542

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
#        keyword                                          embedding
# 0    instagram  [-0.054293513, -0.039209902, -0.00760528, 0.00...
# 1          buy  [-0.06259999, 0.024197826, -0.03591993, -0.008...
# 2  accessories  [-0.085195646, 0.08092506, 0.007724969, 0.0207...
# 3   affordable  [0.036962684, 0.050644796, -0.0030001677, 0.09...
# 4         lace  [-0.09744219, 0.03276038, -0.030828068, 0.0224...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=50, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#        keyword                                          embedding  \
# 0    instagram  [-0.054293513, -0.039209902, -0.00760528, 0.00...
# 1          buy  [-0.06259999, 0.024197826, -0.03591993, -0.008...
# 2  accessories  [-0.085195646, 0.08092506, 0.007724969, 0.0207...
# 3   affordable  [0.036962684, 0.050644796, -0.0030001677, 0.09...
# 4         lace  [-0.09744219, 0.03276038, -0.030828068, 0.0224...
#
#    cluster_label
# 0              5
# 1             29
# 2             33
# 3             34
# 4             49

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: '39 hair beauty',
#  1: 'beauty line',
#  2: 'summers freshness',
#  3: 'beautyproducts browmapping',
#  4: 'women gorgeous',
#  5: 'sephora',
#  6: 'scents',
#  7: 'luxurybeauty',
#  8: 'hair accessories',
#  9: 'straightcurlzz beauty salon',
#  10: 'mmbeauty',
#  11: 'beauty shorts',
#  12: 'plum vanilla',
#  13: 'selfcare glowup beauty',
#  14: 'beauty beauty',
#  15: 'review learn description',
#  16: 'recommendations',
#  17: 'beauty saloon',
#  18: 'infinite beautye lash',
#  19: 'hairombre',
#  20: 'beauty products',
#  21: 'balm company',
#  22: 'perfume fragrance',
#  23: 'beautyparlour',
#  24: 'blondhair',
#  25: 'bodycream',
#  26: 'jiwa beauty',
#  27: 'care hair',
#  28: 'haircare hair',
#  29: 'buy',
#  30: 'hair beauty',
#  31: 'beautysecrets',
#  32: 'beautician',
#  33: 'accessories officialfashionbeauty',
#  34: 'affordablebodymist',
#  35: 'best lash serum',
#  36: 'clinic',
#  37: 'senescence shorts anti',
#  38: 'real hair',
#  39: 'love million colors',
#  40: 'fashionbeauty',
#  41: 'naturesglow',
#  42: 'brand',
#  43: 'beauty amp',
#  44: 'beauty peach milk',
#  45: 'niharika jain fashion',
#  46: 'stylish',
#  47: 'amazon',
#  48: 'belle peau',
#  49: 'lace'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      537              Transformation hair colour correction
# 2    25429                        Huda Beauty UK London Event
# 3    26244  The Jersey Beauty guide to using Dermalogica e...
# 4    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  Helping clients achieve there hair goals. \nco...
# 2  We worked with the HUDA Beauty UK team to film...
# 3  In this video, Jen from Jersey Beauty chats to...
# 4                                     no description
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                 []
# 2  ['huda beauty', 'huda london', 'huda london ev...
# 3  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                 []
#
#                                           clean_text     keywords  \
# 0  five best anti ageing facial exercises look yo...  [instagram]
# 1  transformation hair colour correction helping ...  [instagram]
# 2  huda beauty uk london event we worked with the...  [instagram]
# 3  the jersey beauty guide to using dermalogica e...  [instagram]
# 4  tone n glow face wash for crystal clear skin n...  [instagram]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Beauty Reviews & Brands             0.591229        161          4
# 1  Beauty Reviews & Brands             0.591229         83          2
# 2  Beauty Reviews & Brands             0.591229        121          3
# 3  Beauty Reviews & Brands             0.591229       2228         28
# 4  Beauty Reviews & Brands             0.591229      25959        341
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             1         0.031056  219357.518293  4787.326665     59.469033
# 1             0         0.024096  219357.518293  4787.326665     59.469033
# 2             1         0.033058  219357.518293  4787.326665     59.469033
# 3             0         0.012567  219357.518293  4787.326665     59.469033
# 4           166         0.019531  219357.518293  4787.326665     59.469033
#
#    avg_engagement_rate new_keywords
# 0              0.04542    [sephora]
# 1              0.04542    [sephora]
# 2              0.04542    [sephora]
# 3              0.04542    [sephora]
# 4              0.04542    [sephora]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      537              Transformation hair colour correction
# 2    25429                        Huda Beauty UK London Event
# 3    26244  The Jersey Beauty guide to using Dermalogica e...
# 4    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  Helping clients achieve there hair goals. \nco...
# 2  We worked with the HUDA Beauty UK team to film...
# 3  In this video, Jen from Jersey Beauty chats to...
# 4                                     no description
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                 []
# 2  ['huda beauty', 'huda london', 'huda london ev...
# 3  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                 []
#
#                                           clean_text     keywords  \
# 0  five best anti ageing facial exercises look yo...  [instagram]
# 1  transformation hair colour correction helping ...  [instagram]
# 2  huda beauty uk london event we worked with the...  [instagram]
# 3  the jersey beauty guide to using dermalogica e...  [instagram]
# 4  tone n glow face wash for crystal clear skin n...  [instagram]
#
#                   category  category_confidence  viewCount  likeCount  \
# 0  Beauty Reviews & Brands             0.591229        161          4
# 1  Beauty Reviews & Brands             0.591229         83          2
# 2  Beauty Reviews & Brands             0.591229        121          3
# 3  Beauty Reviews & Brands             0.591229       2228         28
# 4  Beauty Reviews & Brands             0.591229      25959        341
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             1         0.031056  219357.518293  4787.326665     59.469033
# 1             0         0.024096  219357.518293  4787.326665     59.469033
# 2             1         0.033058  219357.518293  4787.326665     59.469033
# 3             0         0.012567  219357.518293  4787.326665     59.469033
# 4           166         0.019531  219357.518293  4787.326665     59.469033
#
#    avg_engagement_rate new_keywords
# 0              0.04542    [sephora]
# 1              0.04542    [sephora]
# 2              0.04542    [sephora]
# 3              0.04542    [sephora]
# 4              0.04542    [sephora]
# new_keywords
# sephora                              5487
# women gorgeous                       1225
# beauty beauty                         670
# luxurybeauty                          664
# accessories officialfashionbeauty     598
# beauty products                       572
# lace                                  506
# haircare hair                         468
# hair accessories                      437
# stylish                               370
# perfume fragrance                     357
# beautysecrets                         341
# jiwa beauty                           280
# beautyparlour                         242
# beautician                            210
# brand                                 191
# hair beauty                           189
# affordablebodymist                    152
# fashionbeauty                         145
# beauty shorts                         129
# amazon                                127
# best lash serum                       120
# infinite beautye lash                 120
# selfcare glowup beauty                106
# beauty line                            70
# hairombre                              70
# blondhair                              66
# real hair                              63
# senescence shorts anti                 62
# beauty saloon                          59
# beauty amp                             55
# beautyproducts browmapping             51
# bodycream                              46
# scents                                 40
# clinic                                 37
# buy                                    36
# 39 hair beauty                         33
# balm company                           31
# plum vanilla                           31
# beauty peach milk                      28
# naturesglow                            24
# summers freshness                      17
# review learn description               15
# mmbeauty                               13
# straightcurlzz beauty salon            12
# belle peau                              8
# care hair                               6
# love million colors                     6
# niharika jain fashion                   6
# recommendations                         5
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0     6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1      537              Transformation hair colour correction
# 2    25429                        Huda Beauty UK London Event
# 3    26244  The Jersey Beauty guide to using Dermalogica e...
# 4    64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
#
#                                          description  \
# 0  #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1  Helping clients achieve there hair goals. \nco...
# 2  We worked with the HUDA Beauty UK team to film...
# 3  In this video, Jen from Jersey Beauty chats to...
# 4                                     no description
#
#                                                 tags  \
# 0  ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                 []
# 2  ['huda beauty', 'huda london', 'huda london ev...
# 3  ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                 []
#
#                                           clean_text                 category  \
# 0  five best anti ageing facial exercises look yo...  Beauty Reviews & Brands
# 1  transformation hair colour correction helping ...  Beauty Reviews & Brands
# 2  huda beauty uk london event we worked with the...  Beauty Reviews & Brands
# 3  the jersey beauty guide to using dermalogica e...  Beauty Reviews & Brands
# 4  tone n glow face wash for crystal clear skin n...  Beauty Reviews & Brands
#
#    category_confidence  viewCount  likeCount  commentCount  engagement_rate  \
# 0             0.591229        161          4             1         0.031056
# 1             0.591229         83          2             0         0.024096
# 2             0.591229        121          3             1         0.033058
# 3             0.591229       2228         28             0         0.012567
# 4             0.591229      25959        341           166         0.019531
#
#        avg_views    avg_likes  avg_comments  avg_engagement_rate keywords
# 0  219357.518293  4787.326665     59.469033              0.04542  sephora
# 1  219357.518293  4787.326665     59.469033              0.04542  sephora
# 2  219357.518293  4787.326665     59.469033              0.04542  sephora
# 3  219357.518293  4787.326665     59.469033              0.04542  sephora
# 4  219357.518293  4787.326665     59.469033              0.04542  sephora

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0      6217  Five Best Anti Ageing Facial Exercises ... Loo...
# 1       537              Transformation hair colour correction
# 2     25429                        Huda Beauty UK London Event
# 3     26244  The Jersey Beauty guide to using Dermalogica e...
# 4     64449   Tone n glow FACE WASH|| FOR CRYSTAL CLEAR SKIN||
# 5     86296               CRYSTALS AND TARAS AVON FASHION SHOW
# 6     48321  Beard transformation Before and After | D-Tan ...
# 7     74246  Ombre hair hanya di vitta beauty salon melyani...
# 8     89804  Hair colour at home / hair colour transformati...
# 9     30805  Pretty lady (hair color) global color with hig...
# 10    32889  KALMA LANG PO KAYO! | SOFT CUT CREASE MAKEUP F...
# 11    27029  Keratin Hair Treatment | Hairs Transformation ...
# 12     2215                                  HAIR SMOOTHING 💇💇
# 13    52285                                     Bodylotion drw
# 14    68550  Best hair color Transformation 😱 New hair colo...
# 15    30843  Only baby powder se beautiful makeup look/ sum...
# 16    81922  2 minutes Everyday Makeup Look with Affordable...
# 17    89622                         beautiful hair clip in bus
# 18    35468                  How to Apply Sunkissed Tan Mousse
# 19     5380           SOFT CONTOURING with The One Contour Kit
#
#                                           description  \
# 0   #AntiAgeingExercises\n#LookYounger\n#TightenYo...
# 1   Helping clients achieve there hair goals. \nco...
# 2   We worked with the HUDA Beauty UK team to film...
# 3   In this video, Jen from Jersey Beauty chats to...
# 4                                      no description
# 5   AVON FASHION-EASY LIVING COLLECTION \nBEST FRI...
# 6   Beard transformation Before and After | D-Tan ...
# 7                                  vitta beauty salon
# 8   #haircolor #haircolorformen \nhair colour for ...
# 9                                      no description
# 10  Music by Singto Conley - Moon Shards [Thematic...
# 11                                    @browneye__king
# 12                                     no description
# 13                               Video dari notiani12
# 14  best hair color Transformation\nhair cut and h...
# 15  Hiii\n        everyone\n\n       Please full w...
# 16  2 minutes Everyday Makeup Look with Affordable...
# 17    silky hair women in bus ...her hair is fansty..
# 18  Get your glow on, girl! We're here to show you...
# 19  Except the eye brow pencil, all products by Or...
#
#                                                  tags  \
# 0   ['#Anti Ageing Facial Exercises', '#Facial Exe...
# 1                                                  []
# 2   ['huda beauty', 'huda london', 'huda london ev...
# 3   ['17-12-2019', 'dermalogica', 'eyecare', 'eye ...
# 4                                                  []
# 5                                                  []
# 6   ['Beard transformation before and After', 'Bea...
# 7                                                  []
# 8   ['how to colour hair at home for men', 'hair c...
# 9                                                  []
# 10  ['makeup', 'makeup video', 'makeup tutorial', ...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14  ['hair', 'hair color', 'color transformation',...
# 15                                                 []
# 16                                                 []
# 17  ['longhair', 'longhaircut', 'hairlove', 'bundr...
# 18  ['fake tan', 'sunkissed', 'sunkissed tan', 'ho...
# 19                                                 []
#
#                                            clean_text  \
# 0   five best anti ageing facial exercises look yo...
# 1   transformation hair colour correction helping ...
# 2   huda beauty uk london event we worked with the...
# 3   the jersey beauty guide to using dermalogica e...
# 4   tone n glow face wash for crystal clear skin n...
# 5   crystals and taras avon fashion show avon fash...
# 6   beard transformation before and after d tan fa...
# 7   ombre hair hanya di vitta beauty salon melyani...
# 8   hair colour at home hair colour transformation...
# 9   pretty lady hair color global color with highl...
# 10  kalma lang po kayo soft cut crease makeup ft a...
# 11  keratin hair treatment hairs transformation ak...
# 12                      hair smoothing no description
# 13                bodylotion drw video dari notiani12
# 14  best hair color transformation new hair color ...
# 15  only baby powder se beautiful makeup look suma...
# 16  2 minutes everyday makeup look with affordable...
# 17  beautiful hair clip in bus silky hair women in...
# 18  how to apply sunkissed tan mousse get your glo...
# 19  soft contouring with the one contour kit excep...
#
#                    category  category_confidence  viewCount  likeCount  \
# 0   Beauty Reviews & Brands             0.591229        161          4
# 1   Beauty Reviews & Brands             0.591229         83          2
# 2   Beauty Reviews & Brands             0.591229        121          3
# 3   Beauty Reviews & Brands             0.591229       2228         28
# 4   Beauty Reviews & Brands             0.591229      25959        341
# 5   Beauty Reviews & Brands             0.591229        197          6
# 6   Beauty Reviews & Brands             0.591229        254         10
# 7   Beauty Reviews & Brands             0.591229         58          1
# 8   Beauty Reviews & Brands             0.591229       5556        112
# 9   Beauty Reviews & Brands             0.591229        377          7
# 10  Beauty Reviews & Brands             0.591229      85924       1006
# 11  Beauty Reviews & Brands             0.591229       1285         95
# 12  Beauty Reviews & Brands             0.591229        107         17
# 13  Beauty Reviews & Brands             0.591229         33          5
# 14  Beauty Reviews & Brands             0.591229         91          8
# 15  Beauty Reviews & Brands             0.591229        205         18
# 16  Beauty Reviews & Brands             0.591229       3892        169
# 17  Beauty Reviews & Brands             0.591229        960         13
# 18  Beauty Reviews & Brands             0.591229       6966         46
# 19  Beauty Reviews & Brands             0.591229         43          1
#
#     commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0              1         0.031056  219357.518293  4787.326665     59.469033
# 1              0         0.024096  219357.518293  4787.326665     59.469033
# 2              1         0.033058  219357.518293  4787.326665     59.469033
# 3              0         0.012567  219357.518293  4787.326665     59.469033
# 4            166         0.019531  219357.518293  4787.326665     59.469033
# 5              3         0.045685  219357.518293  4787.326665     59.469033
# 6              1         0.043307  219357.518293  4787.326665     59.469033
# 7              0         0.017241  219357.518293  4787.326665     59.469033
# 8              7         0.021418  219357.518293  4787.326665     59.469033
# 9              0         0.018568  219357.518293  4787.326665     59.469033
# 10           126         0.013174  219357.518293  4787.326665     59.469033
# 11             6         0.078599  219357.518293  4787.326665     59.469033
# 12             0         0.158879  219357.518293  4787.326665     59.469033
# 13             0         0.151515  219357.518293  4787.326665     59.469033
# 14             0         0.087912  219357.518293  4787.326665     59.469033
# 15            22         0.195122  219357.518293  4787.326665     59.469033
# 16            17         0.047790  219357.518293  4787.326665     59.469033
# 17             0         0.013542  219357.518293  4787.326665     59.469033
# 18             2         0.006891  219357.518293  4787.326665     59.469033
# 19             0         0.023256  219357.518293  4787.326665     59.469033
#
#     avg_engagement_rate keywords                publishedAt
# 0               0.04542  sephora  2020-01-01 14:28:59+00:00
# 1               0.04542  sephora  2020-01-01 16:31:43+00:00
# 2               0.04542  sephora  2020-01-02 13:08:50+00:00
# 3               0.04542  sephora  2020-01-03 15:32:39+00:00
# 4               0.04542  sephora  2020-01-03 19:01:31+00:00
# 5               0.04542  sephora  2020-01-04 06:13:56+00:00
# 6               0.04542  sephora  2020-01-04 09:58:50+00:00
# 7               0.04542  sephora  2020-01-04 12:41:49+00:00
# 8               0.04542  sephora  2020-01-04 13:05:02+00:00
# 9               0.04542  sephora  2020-01-04 13:16:58+00:00
# 10              0.04542  sephora  2020-01-04 13:59:43+00:00
# 11              0.04542  sephora  2020-01-05 08:35:20+00:00
# 12              0.04542  sephora  2020-01-05 10:51:41+00:00
# 13              0.04542  sephora  2020-01-05 13:28:23+00:00
# 14              0.04542  sephora  2020-01-05 18:23:48+00:00
# 15              0.04542  sephora  2020-01-05 18:24:11+00:00
# 16              0.04542  sephora  2020-01-06 06:30:01+00:00
# 17              0.04542  sephora  2020-01-06 06:46:50+00:00
# 18              0.04542  sephora  2020-01-06 08:49:35+00:00
# 19              0.04542  sephora  2020-01-06 09:31:11+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#           keyword  velocity  engagement_rate    phase
#        beauty amp      21.5         0.033959 Emerging
#   best lash serum      10.0         0.025319 Emerging
#         real hair       9.0         0.031655 Emerging
#     beautysecrets       5.5         0.022124 Emerging
#             brand       3.0         0.029831 Emerging
#       jiwa beauty       1.5         0.033375 Emerging
#         care hair       1.5         0.024792 Emerging
# beauty peach milk       1.5         0.021528 Emerging
#         bodycream       1.5         0.020424 Emerging
#       hair beauty       1.0         0.026211 Emerging
#
# 🔝 Top 10 Growing keywords:
#                  keyword  velocity  engagement_rate   phase
#           women gorgeous      24.0         0.038698 Growing
#   senescence shorts anti      14.5         0.039390 Growing
#        perfume fragrance       7.0         0.044401 Growing
#       affordablebodymist       5.0         0.042954 Growing
#   selfcare glowup beauty       5.0         0.038258 Growing
#             plum vanilla       2.0         0.039882 Growing
#                  stylish       1.0         0.041462 Growing
#                   scents       1.0         0.045379 Growing
#                     lace       0.5         0.040192 Growing
# review learn description       0.5         0.048637 Growing
#
# 🔝 Top 10 Peaking keywords:
#                           keyword  velocity  engagement_rate   phase
#                     beauty saloon      -2.0         0.053046 Peaking
#             niharika jain fashion      -0.5         0.052333 Peaking
#                       beauty line      -4.5         0.047812 Peaking
#                           sephora      -6.0         0.047133 Peaking
#                      luxurybeauty      -3.5         0.041261 Peaking
# accessories officialfashionbeauty     -20.5         0.041232 Peaking
#                  hair accessories      -5.5         0.040377 Peaking
#                    39 hair beauty      -3.5         0.040323 Peaking
#                            amazon      -0.5         0.038562 Peaking
#                     beauty beauty     -14.0         0.038415 Peaking
#
# 🔝 Top 10 Decaying keywords:
#                     keyword  velocity  engagement_rate    phase
#       infinite beautye lash      -9.0         0.023777 Decaying
#                  beautician      -3.5         0.035317 Decaying
#                    mmbeauty      -3.0         0.007983 Decaying
#               beautyparlour      -2.0         0.029890 Decaying
#                   hairombre      -1.5         0.031190 Decaying
#         love million colors      -1.5         0.023456 Decaying
#               fashionbeauty      -1.0         0.031876 Decaying
# straightcurlzz beauty salon      -1.0         0.019855 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("brab_keyword_trend_phases.csv", index=False)
print("✅ Saved to brab_keyword_trend_phases.csv")
# Out:
# ✅ Saved to brab_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#                              keyword      velocity  engagement_rate     phase
# 0                     39 hair beauty -3.500000e+00         0.040323   Peaking
# 1  accessories officialfashionbeauty -2.050000e+01         0.041232   Peaking
# 2                 affordablebodymist  5.000000e+00         0.042954   Growing
# 3                             amazon -5.000000e-01         0.038562   Peaking
# 4                       balm company  8.627962e-16         0.020719  Emerging

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0  Emerging     17
# 1   Growing     14
# 2   Peaking     11
# 3  Decaying      8
