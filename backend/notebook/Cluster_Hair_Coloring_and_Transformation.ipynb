# %%
# !pip install pandas numpy matplotlib seaborn plotly scikit-learn wordcloud
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df = pd.read_csv("/content/Hair_Coloring_and_Transformation.csv")
display(df.head())
# Out:
#    videoId                                              title  \
# 0    13790          Caramel Brunette sun-kissed highlights...
# 1    13790          Caramel Brunette sun-kissed highlights...
# 2    13790          Caramel Brunette sun-kissed highlights...
# 3    36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4    79418  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                          description  \
# 0  Book Johnny Ramirez for a new Lived in Color l...
# 1  Book Johnny Ramirez for a new Lived in Color l...
# 2  Book Johnny Ramirez for a new Lived in Color l...
# 3  DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                 tags  \
# 0  ['brunettes', 'redheads', 'blondes', 'highligh...
# 1  ['brunettes', 'redheads', 'blondes', 'highligh...
# 2  ['brunettes', 'redheads', 'blondes', 'highligh...
# 3  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                           clean_text     keywords  \
# 0  caramel brunette sun kissed highlights book jo...       blonde
# 1  caramel brunette sun kissed highlights book jo...        color
# 2  caramel brunette sun kissed highlights book jo...  lived color
# 3  models chandana amp zenita applying hairgel fo...   hairstyles
# 4  models chandana amp zenita applying hairgel fo...   hairstyles
#
#                          category  category_confidence  viewCount  likeCount  \
# 0  Hair Coloring & Transformation             0.570098        469          3
# 1  Hair Coloring & Transformation             0.582803        469          3
# 2  Hair Coloring & Transformation             0.527105        469          3
# 3  Hair Coloring & Transformation             0.642659       9405        133
# 4  Hair Coloring & Transformation             0.642659       2718         55
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             0         0.006397  181008.830703  5768.048901     49.958269
# 1             0         0.006397  181008.830703  5768.048901     49.958269
# 2             0         0.006397  181008.830703  5768.048901     49.958269
# 3            20         0.016268  181008.830703  5768.048901     49.958269
# 4             4         0.021707  181008.830703  5768.048901     49.958269
#
#    avg_engagement_rate
# 0             0.034044
# 1             0.034044
# 2             0.034044
# 3             0.034044
# 4             0.034044

# %% [markdown]
# # Task
# Embed and cluster keywords from the "keywords" column of the "Beauty_Reviews_and_Brands" dataset based on their relevance to the "clean_text" column, reducing the number of unique keywords to a maximum of 50, and update the dataset with the new representative keywords.

# %% [markdown]
# ## Load and prepare data
#
# ### Subtask:
# Load the dataset and preprocess the 'clean_text' and 'keywords' columns. This includes converting the 'keywords' column to a list of keywords.

# %% [markdown]
# **Reasoning**:
# Load the dataset and convert the 'keywords' column to a list.

# %%
import pandas as pd
import ast

df = pd.read_csv("/content/Hair_Coloring_and_Transformation.csv")

def safe_string_to_list(s):
    try:
        return ast.literal_eval(s) if isinstance(s, str) and s.startswith('[') and s.endswith(']') else [s]
    except (ValueError, SyntaxError):
        return [s] if isinstance(s, str) else []

df['keywords'] = df['keywords'].apply(safe_string_to_list)

display(df.head())
# Out:
#    videoId                                              title  \
# 0    13790          Caramel Brunette sun-kissed highlights...
# 1    13790          Caramel Brunette sun-kissed highlights...
# 2    13790          Caramel Brunette sun-kissed highlights...
# 3    36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4    79418  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                          description  \
# 0  Book Johnny Ramirez for a new Lived in Color l...
# 1  Book Johnny Ramirez for a new Lived in Color l...
# 2  Book Johnny Ramirez for a new Lived in Color l...
# 3  DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                 tags  \
# 0  ['brunettes', 'redheads', 'blondes', 'highligh...
# 1  ['brunettes', 'redheads', 'blondes', 'highligh...
# 2  ['brunettes', 'redheads', 'blondes', 'highligh...
# 3  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                           clean_text       keywords  \
# 0  caramel brunette sun kissed highlights book jo...       [blonde]
# 1  caramel brunette sun kissed highlights book jo...        [color]
# 2  caramel brunette sun kissed highlights book jo...  [lived color]
# 3  models chandana amp zenita applying hairgel fo...   [hairstyles]
# 4  models chandana amp zenita applying hairgel fo...   [hairstyles]
#
#                          category  category_confidence  viewCount  likeCount  \
# 0  Hair Coloring & Transformation             0.570098        469          3
# 1  Hair Coloring & Transformation             0.582803        469          3
# 2  Hair Coloring & Transformation             0.527105        469          3
# 3  Hair Coloring & Transformation             0.642659       9405        133
# 4  Hair Coloring & Transformation             0.642659       2718         55
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             0         0.006397  181008.830703  5768.048901     49.958269
# 1             0         0.006397  181008.830703  5768.048901     49.958269
# 2             0         0.006397  181008.830703  5768.048901     49.958269
# 3            20         0.016268  181008.830703  5768.048901     49.958269
# 4             4         0.021707  181008.830703  5768.048901     49.958269
#
#    avg_engagement_rate
# 0             0.034044
# 1             0.034044
# 2             0.034044
# 3             0.034044
# 4             0.034044

# %% [markdown]
# ## Embed keywords
#
# ### Subtask:
# Generate embeddings for each unique keyword using a pre-trained language model.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating embeddings for unique keywords. This involves extracting unique keywords, initializing a sentence transformer model, and then generating embeddings using the model. The code block performs these steps sequentially.

# %%
from sentence_transformers import SentenceTransformer

unique_keywords = df['keywords'].explode().unique().tolist()

model = SentenceTransformer('all-MiniLM-L6-v2')

keyword_embeddings = model.encode(unique_keywords)

keyword_embedding_df = pd.DataFrame({'keyword': unique_keywords, 'embedding': list(keyword_embeddings)})
display(keyword_embedding_df.head())
# Out:
#               keyword                                          embedding
# 0              blonde  [-0.037850324, -0.07085662, 0.021708766, 0.024...
# 1               color  [-0.029904583, 0.059637483, -0.050713286, 0.00...
# 2         lived color  [-0.030664, 0.060893025, -0.022684086, 0.04585...
# 3          hairstyles  [-0.041020725, 0.0288638, 0.05281182, 0.010095...
# 4  hairstyle tutorial  [-0.041630425, 0.014325188, 0.0324061, -0.0211...

# %% [markdown]
# ## Cluster keywords
#
# ### Subtask:
# Apply a clustering algorithm (e.g., K-Means) to group similar keyword embeddings into at most 50 clusters.

# %% [markdown]
# **Reasoning**:
# Apply KMeans clustering to the keyword embeddings to group similar keywords into a maximum of 50 clusters as instructed.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=40, random_state=42, n_init=10)
kmeans.fit(list(keyword_embedding_df['embedding']))

keyword_embedding_df['cluster_label'] = kmeans.labels_
display(keyword_embedding_df.head())
# Out:
#               keyword                                          embedding  \
# 0              blonde  [-0.037850324, -0.07085662, 0.021708766, 0.024...
# 1               color  [-0.029904583, 0.059637483, -0.050713286, 0.00...
# 2         lived color  [-0.030664, 0.060893025, -0.022684086, 0.04585...
# 3          hairstyles  [-0.041020725, 0.0288638, 0.05281182, 0.010095...
# 4  hairstyle tutorial  [-0.041630425, 0.014325188, 0.0324061, -0.0211...
#
#    cluster_label
# 0              9
# 1              3
# 2              3
# 3             27
# 4              4

# %% [markdown]
# ## Map keywords to representative keywords
#
# ### Subtask:
# For each cluster, identify a representative keyword (e.g., the keyword closest to the cluster centroid) and create a mapping from all keywords in the cluster to this representative keyword.

# %% [markdown]
# **Reasoning**:
# Calculate the distance of each keyword embedding to its cluster centroid and identify the keyword closest to the centroid as the representative for each cluster. Then, create a dictionary mapping each keyword to its representative.

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate cluster centroids
cluster_centroids = kmeans.cluster_centers_

# Calculate distances from each keyword to its cluster centroid
distances = euclidean_distances(list(keyword_embedding_df['embedding']), cluster_centroids)

# Find the index of the representative keyword for each cluster
representative_keyword_indices = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_indices = keyword_embedding_df[keyword_embedding_df['cluster_label'] == cluster_label].index
    distances_to_centroid = distances[cluster_indices, cluster_label]
    representative_index_in_cluster = cluster_indices[distances_to_centroid.argmin()]
    representative_keyword_indices[cluster_label] = representative_index_in_cluster

# Create a mapping from cluster label to representative keyword
cluster_to_representative_keyword = {
    cluster_label: keyword_embedding_df.loc[index, 'keyword']
    for cluster_label, index in representative_keyword_indices.items()
}

# Create a mapping from all keywords to their representative keywords
keyword_to_cluster = keyword_embedding_df.set_index('keyword')['cluster_label'].to_dict()
keyword_to_representative = {
    keyword: cluster_to_representative_keyword[cluster_label]
    for keyword, cluster_label in keyword_to_cluster.items()
}

# Store the mapping
representative_keywords = cluster_to_representative_keyword

display(representative_keywords)
# Out:
# {0: 'hairgram',
#  1: 'blonde hair transformation',
#  2: 'hair colour hair',
#  3: 'color',
#  4: 'hairstyle tutorial',
#  5: 'leaveout sewin hairstyle',
#  6: 'hairtransformation',
#  7: 'natural hair cut',
#  8: 'hair treatment',
#  9: 'blond hairstyle',
#  10: 'diyhairstyle hairstyle',
#  11: 'curly hair',
#  12: 'highlights base colour',
#  13: 'hairtransformation haircolor',
#  14: 'hairtreatment haircare',
#  15: 'whitening',
#  16: 'glowup transformation',
#  17: 'transform look',
#  18: 'beautiful hair',
#  19: 'hair highlights',
#  20: 'colourtransformation',
#  21: 'hair hair',
#  22: 'short hair',
#  23: 'hair styles',
#  24: 'mounir transformation haircolor',
#  25: 'blonde balayage description',
#  26: 'besthaircolor',
#  27: 'hairstyles',
#  28: 'transformation',
#  29: 'hair balayage',
#  30: 'skin transformation',
#  31: 'wig',
#  32: 'hair journey',
#  33: 'amazing global hair',
#  34: 'braids',
#  35: 'hair smoothing',
#  36: 'shading',
#  37: 'hairoil',
#  38: 'bleach hair',
#  39: 'transformation color balayage'}

# %% [markdown]
# ## Replace keywords in DataFrame
#
# ### Subtask:
# Apply the mapping to the 'keywords' column in the original DataFrame to replace the original keywords with the representative keywords.

# %% [markdown]
# **Reasoning**:
# Iterate through the 'keywords' column of the DataFrame, and for each list of keywords, create a new list where each original keyword is replaced by its representative keyword using the `keyword_to_representative` dictionary.

# %%
# Replace keywords in the DataFrame with representative keywords
df['new_keywords'] = df['keywords'].apply(lambda keyword_list: [
    keyword_to_representative.get(keyword, keyword) for keyword in keyword_list
])

# Display the head of the updated df to show the new column
display(df.head())
# Out:
#    videoId                                              title  \
# 0    13790          Caramel Brunette sun-kissed highlights...
# 1    13790          Caramel Brunette sun-kissed highlights...
# 2    13790          Caramel Brunette sun-kissed highlights...
# 3    36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4    79418  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                          description  \
# 0  Book Johnny Ramirez for a new Lived in Color l...
# 1  Book Johnny Ramirez for a new Lived in Color l...
# 2  Book Johnny Ramirez for a new Lived in Color l...
# 3  DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                 tags  \
# 0  ['brunettes', 'redheads', 'blondes', 'highligh...
# 1  ['brunettes', 'redheads', 'blondes', 'highligh...
# 2  ['brunettes', 'redheads', 'blondes', 'highligh...
# 3  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                           clean_text       keywords  \
# 0  caramel brunette sun kissed highlights book jo...       [blonde]
# 1  caramel brunette sun kissed highlights book jo...        [color]
# 2  caramel brunette sun kissed highlights book jo...  [lived color]
# 3  models chandana amp zenita applying hairgel fo...   [hairstyles]
# 4  models chandana amp zenita applying hairgel fo...   [hairstyles]
#
#                          category  category_confidence  viewCount  likeCount  \
# 0  Hair Coloring & Transformation             0.570098        469          3
# 1  Hair Coloring & Transformation             0.582803        469          3
# 2  Hair Coloring & Transformation             0.527105        469          3
# 3  Hair Coloring & Transformation             0.642659       9405        133
# 4  Hair Coloring & Transformation             0.642659       2718         55
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             0         0.006397  181008.830703  5768.048901     49.958269
# 1             0         0.006397  181008.830703  5768.048901     49.958269
# 2             0         0.006397  181008.830703  5768.048901     49.958269
# 3            20         0.016268  181008.830703  5768.048901     49.958269
# 4             4         0.021707  181008.830703  5768.048901     49.958269
#
#    avg_engagement_rate       new_keywords
# 0             0.034044  [blond hairstyle]
# 1             0.034044            [color]
# 2             0.034044            [color]
# 3             0.034044       [hairstyles]
# 4             0.034044       [hairstyles]

# %% [markdown]
# ## Analyze and display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'new_keywords' column and analyze the distribution of the new keywords.

# %% [markdown]
# **Reasoning**:
# Display the updated DataFrame with the new column and calculate the value counts of the new keywords to analyze their distribution.

# %%
# Display the head of the updated df to show the new column
display(df.head())

# Analyze the distribution of the new keywords
new_keyword_counts = df['new_keywords'].explode().value_counts()
display(new_keyword_counts)
# Out:
#    videoId                                              title  \
# 0    13790          Caramel Brunette sun-kissed highlights...
# 1    13790          Caramel Brunette sun-kissed highlights...
# 2    13790          Caramel Brunette sun-kissed highlights...
# 3    36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4    79418  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                          description  \
# 0  Book Johnny Ramirez for a new Lived in Color l...
# 1  Book Johnny Ramirez for a new Lived in Color l...
# 2  Book Johnny Ramirez for a new Lived in Color l...
# 3  DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                 tags  \
# 0  ['brunettes', 'redheads', 'blondes', 'highligh...
# 1  ['brunettes', 'redheads', 'blondes', 'highligh...
# 2  ['brunettes', 'redheads', 'blondes', 'highligh...
# 3  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                           clean_text       keywords  \
# 0  caramel brunette sun kissed highlights book jo...       [blonde]
# 1  caramel brunette sun kissed highlights book jo...        [color]
# 2  caramel brunette sun kissed highlights book jo...  [lived color]
# 3  models chandana amp zenita applying hairgel fo...   [hairstyles]
# 4  models chandana amp zenita applying hairgel fo...   [hairstyles]
#
#                          category  category_confidence  viewCount  likeCount  \
# 0  Hair Coloring & Transformation             0.570098        469          3
# 1  Hair Coloring & Transformation             0.582803        469          3
# 2  Hair Coloring & Transformation             0.527105        469          3
# 3  Hair Coloring & Transformation             0.642659       9405        133
# 4  Hair Coloring & Transformation             0.642659       2718         55
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             0         0.006397  181008.830703  5768.048901     49.958269
# 1             0         0.006397  181008.830703  5768.048901     49.958269
# 2             0         0.006397  181008.830703  5768.048901     49.958269
# 3            20         0.016268  181008.830703  5768.048901     49.958269
# 4             4         0.021707  181008.830703  5768.048901     49.958269
#
#    avg_engagement_rate       new_keywords
# 0             0.034044  [blond hairstyle]
# 1             0.034044            [color]
# 2             0.034044            [color]
# 3             0.034044       [hairstyles]
# 4             0.034044       [hairstyles]
# new_keywords
# hairtransformation                 3496
# transformation                     3069
# color                              2147
# short hair                         1737
# hairstyles                         1718
# hair colour hair                   1071
# hair hair                           879
# wig                                 870
# hair treatment                      776
# blond hairstyle                     742
# hairtreatment haircare              415
# curly hair                          365
# natural hair cut                    292
# hair highlights                     240
# colourtransformation                196
# hairtransformation haircolor        189
# beautiful hair                      147
# whitening                           146
# hair balayage                       137
# hair smoothing                      118
# hairoil                             118
# hair styles                          84
# hairgram                             59
# highlights base colour               55
# bleach hair                          46
# hairstyle tutorial                   44
# hair journey                         28
# transformation color balayage        28
# blonde hair transformation           22
# braids                               22
# besthaircolor                        21
# transform look                       18
# mounir transformation haircolor      16
# diyhairstyle hairstyle               16
# shading                              14
# blonde balayage description          11
# skin transformation                  10
# amazing global hair                  10
# leaveout sewin hairstyle              9
# glowup transformation                 5
# Name: count, dtype: int64

# %% [markdown]
# ## Finish task
#
# Describe the results and the implications of the new keyword distribution.

# %%
# Drop the original 'keywords' column
df = df.drop('keywords', axis=1)

# Rename the 'new_keywords' column to 'keywords'
df = df.rename(columns={'new_keywords': 'keywords'})

# Remove the square brackets from the 'keywords' column
df['keywords'] = df['keywords'].apply(lambda x: ', '.join(x).replace('[', '').replace(']', '').replace("'", ""))

df.head()
# Out:
#    videoId                                              title  \
# 0    13790          Caramel Brunette sun-kissed highlights...
# 1    13790          Caramel Brunette sun-kissed highlights...
# 2    13790          Caramel Brunette sun-kissed highlights...
# 3    36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4    79418  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                          description  \
# 0  Book Johnny Ramirez for a new Lived in Color l...
# 1  Book Johnny Ramirez for a new Lived in Color l...
# 2  Book Johnny Ramirez for a new Lived in Color l...
# 3  DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                 tags  \
# 0  ['brunettes', 'redheads', 'blondes', 'highligh...
# 1  ['brunettes', 'redheads', 'blondes', 'highligh...
# 2  ['brunettes', 'redheads', 'blondes', 'highligh...
# 3  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                           clean_text  \
# 0  caramel brunette sun kissed highlights book jo...
# 1  caramel brunette sun kissed highlights book jo...
# 2  caramel brunette sun kissed highlights book jo...
# 3  models chandana amp zenita applying hairgel fo...
# 4  models chandana amp zenita applying hairgel fo...
#
#                          category  category_confidence  viewCount  likeCount  \
# 0  Hair Coloring & Transformation             0.570098        469          3
# 1  Hair Coloring & Transformation             0.582803        469          3
# 2  Hair Coloring & Transformation             0.527105        469          3
# 3  Hair Coloring & Transformation             0.642659       9405        133
# 4  Hair Coloring & Transformation             0.642659       2718         55
#
#    commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0             0         0.006397  181008.830703  5768.048901     49.958269
# 1             0         0.006397  181008.830703  5768.048901     49.958269
# 2             0         0.006397  181008.830703  5768.048901     49.958269
# 3            20         0.016268  181008.830703  5768.048901     49.958269
# 4             4         0.021707  181008.830703  5768.048901     49.958269
#
#    avg_engagement_rate         keywords
# 0             0.034044  blond hairstyle
# 1             0.034044            color
# 2             0.034044            color
# 3             0.034044       hairstyles
# 4             0.034044       hairstyles

# %%
# Load the cleaned_videos.csv file
cleaned_videos_df = pd.read_csv("/content/cleaned_videos.csv")

# Select only the videoId and publishedAt columns
cleaned_videos_subset = cleaned_videos_df[['videoId', 'publishedAt']]

# Merge the dataframes on videoId
df = df.merge(cleaned_videos_subset, on='videoId', how='left')

# Display the head of the updated df to show the new column
display(df.head(20))
# Out:
#     videoId                                              title  \
# 0     13790          Caramel Brunette sun-kissed highlights...
# 1     13790          Caramel Brunette sun-kissed highlights...
# 2     13790          Caramel Brunette sun-kissed highlights...
# 3     36288  Models Chandana &amp; Zenita Applying HairGel ...
# 4     79418  Models Chandana &amp; Zenita Applying HairGel ...
# 5     38241  Models Chandana &amp; Zenita Applying HairGel ...
# 6     12371  Models Chandana &amp; Zenita Applying HairGel ...
# 7     13000  Models Chandana &amp; Zenita Applying HairGel ...
# 8     86600  Models Chandana &amp; Zenita Applying HairGel ...
# 9     72125  Models Chandana &amp; Zenita Applying HairGel ...
# 10      666          California sunkissed blonde highlights...
# 11      666          California sunkissed blonde highlights...
# 12      666          California sunkissed blonde highlights...
# 13    41191               Gorgeous Brunette to Blonde Ombre...
# 14    41191               Gorgeous Brunette to Blonde Ombre...
# 15    41191               Gorgeous Brunette to Blonde Ombre...
# 16    71170               Blonde shoulder length highlights...
# 17    71170               Blonde shoulder length highlights...
# 18    71170               Blonde shoulder length highlights...
# 19    73741  Models Chandana &amp; Zenita Applying HairGel ...
#
#                                           description  \
# 0   Book Johnny Ramirez for a new Lived in Color l...
# 1   Book Johnny Ramirez for a new Lived in Color l...
# 2   Book Johnny Ramirez for a new Lived in Color l...
# 3   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 4   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 5   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 6   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 7   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 8   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 9   DM us at Instagram⬇️\nhttps://www.instagram.co...
# 10  From temporary over processed hair to Lived in...
# 11  From temporary over processed hair to Lived in...
# 12  From temporary over processed hair to Lived in...
# 13  Book Johnny Ramirez, the creator of Lived in C...
# 14  Book Johnny Ramirez, the creator of Lived in C...
# 15  Book Johnny Ramirez, the creator of Lived in C...
# 16  Book Johnny Ramirez for a new Lived in Color l...
# 17  Book Johnny Ramirez for a new Lived in Color l...
# 18  Book Johnny Ramirez for a new Lived in Color l...
# 19  DM us at Instagram⬇️\nhttps://www.instagram.co...
#
#                                                  tags  \
# 0   ['brunettes', 'redheads', 'blondes', 'highligh...
# 1   ['brunettes', 'redheads', 'blondes', 'highligh...
# 2   ['brunettes', 'redheads', 'blondes', 'highligh...
# 3   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 4   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 5   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 6   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 7   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 8   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 9   ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
# 10  ['beach blonde', 'johnny ramirez', 'blonde hai...
# 11  ['beach blonde', 'johnny ramirez', 'blonde hai...
# 12  ['beach blonde', 'johnny ramirez', 'blonde hai...
# 13  ['johnny ramirez', 'blonde hair', 'blonde high...
# 14  ['johnny ramirez', 'blonde hair', 'blonde high...
# 15  ['johnny ramirez', 'blonde hair', 'blonde high...
# 16  ['blonde', 'blonde highlights', 'shoulder leng...
# 17  ['blonde', 'blonde highlights', 'shoulder leng...
# 18  ['blonde', 'blonde highlights', 'shoulder leng...
# 19  ['Hair Keeper', 'Bengali hairplay', 'Longhair ...
#
#                                            clean_text  \
# 0   caramel brunette sun kissed highlights book jo...
# 1   caramel brunette sun kissed highlights book jo...
# 2   caramel brunette sun kissed highlights book jo...
# 3   models chandana amp zenita applying hairgel fo...
# 4   models chandana amp zenita applying hairgel fo...
# 5   models chandana amp zenita applying hairgel fo...
# 6   models chandana amp zenita applying hairgel fo...
# 7   models chandana amp zenita applying hairgel fo...
# 8   models chandana amp zenita applying hairgel fo...
# 9   models chandana amp zenita applying hairgel fo...
# 10  california sunkissed blonde highlights from te...
# 11  california sunkissed blonde highlights from te...
# 12  california sunkissed blonde highlights from te...
# 13  gorgeous brunette to blonde ombre book johnny ...
# 14  gorgeous brunette to blonde ombre book johnny ...
# 15  gorgeous brunette to blonde ombre book johnny ...
# 16  blonde shoulder length highlights book johnny ...
# 17  blonde shoulder length highlights book johnny ...
# 18  blonde shoulder length highlights book johnny ...
# 19  models chandana amp zenita applying hairgel fo...
#
#                           category  category_confidence  viewCount  likeCount  \
# 0   Hair Coloring & Transformation             0.570098        469          3
# 1   Hair Coloring & Transformation             0.582803        469          3
# 2   Hair Coloring & Transformation             0.527105        469          3
# 3   Hair Coloring & Transformation             0.642659       9405        133
# 4   Hair Coloring & Transformation             0.642659       2718         55
# 5   Hair Coloring & Transformation             0.642659      11629        144
# 6   Hair Coloring & Transformation             0.642659       7319        100
# 7   Hair Coloring & Transformation             0.642659       2959         49
# 8   Hair Coloring & Transformation             0.642659       6074         76
# 9   Hair Coloring & Transformation             0.642659        888         18
# 10  Hair Coloring & Transformation             0.570098        182          0
# 11  Hair Coloring & Transformation             0.582803        182          0
# 12  Hair Coloring & Transformation             0.527105        182          0
# 13  Hair Coloring & Transformation             0.570098        145          2
# 14  Hair Coloring & Transformation             0.582803        145          2
# 15  Hair Coloring & Transformation             0.527105        145          2
# 16  Hair Coloring & Transformation             0.570098        174          0
# 17  Hair Coloring & Transformation             0.582803        174          0
# 18  Hair Coloring & Transformation             0.527105        174          0
# 19  Hair Coloring & Transformation             0.642659       9340        110
#
#     commentCount  engagement_rate      avg_views    avg_likes  avg_comments  \
# 0              0         0.006397  181008.830703  5768.048901     49.958269
# 1              0         0.006397  181008.830703  5768.048901     49.958269
# 2              0         0.006397  181008.830703  5768.048901     49.958269
# 3             20         0.016268  181008.830703  5768.048901     49.958269
# 4              4         0.021707  181008.830703  5768.048901     49.958269
# 5              9         0.013157  181008.830703  5768.048901     49.958269
# 6             10         0.015029  181008.830703  5768.048901     49.958269
# 7              7         0.018925  181008.830703  5768.048901     49.958269
# 8             11         0.014323  181008.830703  5768.048901     49.958269
# 9              3         0.023649  181008.830703  5768.048901     49.958269
# 10             0         0.000000  181008.830703  5768.048901     49.958269
# 11             0         0.000000  181008.830703  5768.048901     49.958269
# 12             0         0.000000  181008.830703  5768.048901     49.958269
# 13             1         0.020690  181008.830703  5768.048901     49.958269
# 14             1         0.020690  181008.830703  5768.048901     49.958269
# 15             1         0.020690  181008.830703  5768.048901     49.958269
# 16             0         0.000000  181008.830703  5768.048901     49.958269
# 17             0         0.000000  181008.830703  5768.048901     49.958269
# 18             0         0.000000  181008.830703  5768.048901     49.958269
# 19             9         0.012741  181008.830703  5768.048901     49.958269
#
#     avg_engagement_rate         keywords                publishedAt
# 0              0.034044  blond hairstyle  2020-02-04 17:23:27+00:00
# 1              0.034044            color  2020-02-04 17:23:27+00:00
# 2              0.034044            color  2020-02-04 17:23:27+00:00
# 3              0.034044       hairstyles  2020-02-22 18:07:08+00:00
# 4              0.034044       hairstyles  2020-02-24 17:13:40+00:00
# 5              0.034044       hairstyles  2020-02-24 17:16:33+00:00
# 6              0.034044       hairstyles  2020-02-29 06:39:19+00:00
# 7              0.034044       hairstyles  2020-02-29 06:46:56+00:00
# 8              0.034044       hairstyles  2020-03-12 03:00:31+00:00
# 9              0.034044       hairstyles  2020-03-12 03:15:12+00:00
# 10             0.034044  blond hairstyle  2020-03-24 12:58:12+00:00
# 11             0.034044            color  2020-03-24 12:58:12+00:00
# 12             0.034044            color  2020-03-24 12:58:12+00:00
# 13             0.034044  blond hairstyle  2020-03-28 01:09:32+00:00
# 14             0.034044            color  2020-03-28 01:09:32+00:00
# 15             0.034044            color  2020-03-28 01:09:32+00:00
# 16             0.034044  blond hairstyle  2020-04-06 14:14:12+00:00
# 17             0.034044            color  2020-04-06 14:14:12+00:00
# 18             0.034044            color  2020-04-06 14:14:12+00:00
# 19             0.034044       hairstyles  2020-04-12 14:15:56+00:00

# %%
# === Simplified Keyword Trend Detection ===
import pandas as pd
import numpy as np

# Step 1: Preprocess
df["publishedAt"] = pd.to_datetime(df["publishedAt"], errors="coerce")
df = df.dropna(subset=["keywords"]).sort_values("publishedAt")
df["keyword"] = df["keywords"].str.strip().str.lower()
df["month"] = df["publishedAt"].dt.to_period("M")

# Step 2: Aggregate mentions per month + engagement
keyword_time = (
    df.groupby(["keyword", "month"])
      .agg({"videoId":"count", "engagement_rate":"mean"})
      .reset_index()
      .rename(columns={"videoId":"mentions"})
)

# Step 3: Compute recent velocity (last 3 months slope)
def recent_velocity(x):
    if len(x) < 2:
        return 0
    # take last 3 months
    t = np.arange(len(x))[-3:]
    y = x["mentions"].values[-3:]
    return np.polyfit(t, y, 1)[0]

velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# Step 4: Average engagement per keyword
eng = keyword_time.groupby("keyword")["engagement_rate"].mean().reset_index()

# Step 5: Merge velocity + engagement
score_df = velocities.merge(eng, on="keyword", how="left")

# Step 6: Classification thresholds
eng_thresh = score_df["engagement_rate"].median()

def classify_phase(velocity, engagement, v_thresh=0, e_thresh=eng_thresh):
    if velocity > v_thresh and engagement < e_thresh:
        return "Emerging"   # upward mentions, low engagement
    elif velocity > v_thresh and engagement >= e_thresh:
        return "Growing"    # upward mentions, high engagement
    elif velocity <= v_thresh and engagement >= e_thresh:
        return "Peaking"    # slowing mentions, still high engagement
    else:
        return "Decaying"   # losing both mentions and engagement

score_df["phase"] = score_df.apply(
    lambda r: classify_phase(r["velocity"], r["engagement_rate"]), axis=1
)

# Step 7: Ranking logic for Top 10
# - Emerging & Growing → rank by velocity (higher = better momentum)
# - Peaking → rank by engagement_rate (since velocity flat/negative but still resonates)
# - Decaying → rank by velocity (more negative = faster decay)

print("🔝 Top Keywords by Phase\n" + "-"*60)
for phase in ["Emerging", "Growing", "Peaking", "Decaying"]:
    df_phase = score_df[score_df["phase"] == phase].copy()

    if phase in ["Emerging", "Growing"]:
        df_phase = df_phase.sort_values("velocity", ascending=False)
    elif phase == "Peaking":
        df_phase = df_phase.sort_values("engagement_rate", ascending=False)
    else:  # Decaying
        df_phase = df_phase.sort_values("velocity", ascending=True)  # more negative first

    print(f"\n🔝 Top 10 {phase} keywords:")
    print(df_phase.head(10)[["keyword", "velocity", "engagement_rate", "phase"]].to_string(index=False))
# Out:
# 🔝 Top Keywords by Phase
# ------------------------------------------------------------
#
# 🔝 Top 10 Emerging keywords:
#                     keyword  velocity  engagement_rate    phase
#                 hair styles       9.0         0.030933 Emerging
#                 bleach hair       5.5         0.033229 Emerging
#                       color       5.5         0.033597 Emerging
#               hair balayage       3.5         0.030408 Emerging
#                      braids       3.5         0.029453 Emerging
#      diyhairstyle hairstyle       3.0         0.027091 Emerging
#          hairstyle tutorial       2.0         0.024511 Emerging
#         amazing global hair       2.0         0.015976 Emerging
# blonde balayage description       0.5         0.022290 Emerging
#
# 🔝 Top 10 Growing keywords:
#                         keyword     velocity  engagement_rate   phase
#                  transformation 3.600000e+01         0.036854 Growing
#              hairtransformation 2.000000e+01         0.035382 Growing
#                 hair highlights 1.650000e+01         0.039431 Growing
#   transformation color balayage 3.000000e+00         0.036419 Growing
#             skin transformation 2.000000e+00         0.047992 Growing
#                    hair journey 1.500000e+00         0.114979 Growing
#                  hair smoothing 1.000000e+00         0.033850 Growing
# mounir transformation haircolor 5.000000e-01         0.033885 Growing
#            colourtransformation 8.972846e-15         0.042712 Growing
#
# 🔝 Top 10 Peaking keywords:
#                      keyword  velocity  engagement_rate   phase
#                besthaircolor      -3.0         0.052535 Peaking
#               beautiful hair      -1.5         0.046924 Peaking
#     leaveout sewin hairstyle      -1.0         0.042132 Peaking
#       highlights base colour      -1.5         0.041907 Peaking
#                   curly hair      -7.0         0.039095 Peaking
# hairtransformation haircolor      -0.5         0.038350 Peaking
#             hair colour hair      -4.5         0.036807 Peaking
#       hairtreatment haircare     -17.0         0.036475 Peaking
#                          wig     -15.5         0.036184 Peaking
#             natural hair cut      -0.5         0.035496 Peaking
#
# 🔝 Top 10 Decaying keywords:
#                    keyword  velocity  engagement_rate    phase
#                  hair hair     -34.5         0.033489 Decaying
#                  whitening     -21.5         0.017220 Decaying
#                 short hair     -15.0         0.033048 Decaying
#             hair treatment      -8.0         0.032052 Decaying
#                   hairgram      -6.0         0.021430 Decaying
# blonde hair transformation      -2.5         0.013953 Decaying
#      glowup transformation      -1.0         0.011351 Decaying
#            blond hairstyle      -1.0         0.030489 Decaying
#                    hairoil      -0.5         0.031154 Decaying
#             transform look      -0.5         0.014669 Decaying
# /tmp/ipython-input-3666562647.py:9: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["month"] = df["publishedAt"].dt.to_period("M")
# /tmp/ipython-input-3666562647.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   velocities = keyword_time.groupby("keyword").apply(recent_velocity).reset_index(name="velocity")

# %%
# === Step 7: Save to CSV ===
score_df.to_csv("Hair_Coloring_and_Transformation_keyword_trend_phases.csv", index=False)
print("✅ Saved to Hair_Coloring_and_Transformation_keyword_trend_phases.csv")
# Out:
# ✅ Saved to Hair_Coloring_and_Transformation_keyword_trend_phases.csv

# %%
score_df.head()
# Out:
#                keyword  velocity  engagement_rate     phase
# 0  amazing global hair       2.0         0.015976  Emerging
# 1       beautiful hair      -1.5         0.046924   Peaking
# 2        besthaircolor      -3.0         0.052535   Peaking
# 3          bleach hair       5.5         0.033229  Emerging
# 4      blond hairstyle      -1.0         0.030489  Decaying

# %%
phase_counts = score_df['phase'].value_counts().reset_index()
phase_counts.columns = ['Phase', 'Count']
print("Number of keywords in each phase:")
display(phase_counts)
# Out:
# Number of keywords in each phase:
#       Phase  Count
# 0   Peaking     11
# 1  Decaying     11
# 2  Emerging      9
# 3   Growing      9
